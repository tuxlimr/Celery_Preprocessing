# %% [markdown]
# <a href="https://colab.research.google.com/github/tuxlimr/Celery_Preprocessing/blob/master/QuantEngineer_NIFTY_Yahoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
NiftyIT = ['INFY.NS', 'TCS.NS']
NiftyMetal = ['HINDALCO.NS','TATASTEEL.NS','JINDALSTEL.NS', 'VEDL.NS','ICICIBANK.NS']
NiftyTelecom = ['BHARTIARTL.NS','TATACOMM.NS','IDEA.NS']
NityBank = ['HDFCBANK.NS','PNB.NS','SBIN.NS', 'ICICIBANK.NS','AXISBANK.NS','CANBK.NS','BANKBARODA.NS']
NIftyFMCG = ['BAJAJCON.NS','ITC.NS', 'HINDUNILVR.NS', 'DABUR.NS','COLPAL.NS']

ticker = NiftyIT + NiftyMetal + NiftyTelecom + NityBank + NIftyFMCG

# %% [markdown]
# #### Pull Data

# %%
stocks = yf.download(ticker, start="2010-01-01", end="2024-01-01")
# Out:
# [*********************100%%**********************]  21 of 21 completed

# %%
stocks
# Out:
#               Adj Close                                                      \
#             AXISBANK.NS BAJAJCON.NS BANKBARODA.NS BHARTIARTL.NS    CANBK.NS
# Date
# 2010-01-04   180.734619         NaN     83.074020    279.296417  301.685120
# 2010-01-05   184.505615         NaN     85.474243    283.719452  306.979828
# 2010-01-06   181.408661         NaN     85.997795    280.713501  308.492615
# 2010-01-07   182.692978         NaN     86.513275    282.903625  311.026550
# 2010-01-08   185.079468         NaN     86.859619    279.167603  306.752930
# ...                 ...         ...           ...           ...         ...
# 2023-09-15  1027.150024  233.199997    210.800003    936.150024  364.850006
# 2023-09-18  1024.750000  231.699997    217.350006    920.200012  372.250000
# 2023-09-20  1027.300049  229.899994    213.449997    910.700012  371.000000
# 2023-09-21  1014.450012  227.600006    207.149994    917.950012  364.450012
# ...

# %%
stocks.to_csv("Stocks.csv")

# %%
stocks = pd.read_csv("Stocks.csv")

# %%
stocks.head()
# Out:
#    Unnamed: 0           Adj Close  Adj Close.1        Adj Close.2  \
# 0         NaN         AXISBANK.NS  BAJAJCON.NS      BANKBARODA.NS
# 1        Date                 NaN          NaN                NaN
# 2  2010-01-04    180.734619140625          NaN  83.07402038574219
# 3  2010-01-05    184.505615234375          NaN   85.4742431640625
# 4  2010-01-06  181.40866088867188          NaN  85.99779510498047
#
#          Adj Close.3         Adj Close.4         Adj Close.5  \
# 0      BHARTIARTL.NS            CANBK.NS           COLPAL.NS
# 1                NaN                 NaN                 NaN
# 2  279.2964172363281  301.68511962890625   261.8997497558594
# 3  283.7194519042969   306.9798278808594  261.48016357421875
# 4  280.7135009765625  308.49261474609375  262.18585205078125
#
#          Adj Close.6         Adj Close.7         Adj Close.8  ... Volume.11  \
# 0           DABUR.NS         HDFCBANK.NS         HINDALCO.NS  ...   IDEA.NS
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1])
stocks.head()
# Out:
#   Unnamed: 0_level_0   Adj Close                                          \
#   Unnamed: 0_level_1 AXISBANK.NS BAJAJCON.NS BANKBARODA.NS BHARTIARTL.NS
# 0               Date         NaN         NaN           NaN           NaN
# 1         2010-01-04  180.734619         NaN     83.074020    279.296417
# 2         2010-01-05  184.505615         NaN     85.474243    283.719452
# 3         2010-01-06  181.408661         NaN     85.997795    280.713501
# 4         2010-01-07  182.692978         NaN     86.513275    282.903625
#
#                                                               ...     Volume  \
#      CANBK.NS   COLPAL.NS   DABUR.NS HDFCBANK.NS HINDALCO.NS  ...    IDEA.NS
# 0         NaN         NaN        NaN         NaN         NaN  ...        NaN
# 1  301.685120  261.899750  69.688766  153.989594  145.531647  ...  2469242.0
# 2  306.979828  261.480164  71.372673  154.124985  155.945831  ...  7604355.0
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1], index_col=[0])
stocks.head()
# Out:
#              Adj Close                                                      \
#            AXISBANK.NS BAJAJCON.NS BANKBARODA.NS BHARTIARTL.NS    CANBK.NS
# Date
# 2010-01-04  180.734619         NaN     83.074020    279.296417  301.685120
# 2010-01-05  184.505615         NaN     85.474243    283.719452  306.979828
# 2010-01-06  181.408661         NaN     85.997795    280.713501  308.492615
# 2010-01-07  182.692978         NaN     86.513275    282.903625  311.026550
# 2010-01-08  185.079468         NaN     86.859619    279.167603  306.752930
#
#                                                                          ...  \
#              COLPAL.NS   DABUR.NS HDFCBANK.NS HINDALCO.NS HINDUNILVR.NS  ...
# Date                                                                     ...
# 2010-01-04  261.899750  69.688766  153.989594  145.531647    206.463058  ...
# 2010-01-05  261.480164  71.372673  154.124985  155.945831    205.800079  ...
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1], index_col=[0], parse_dates=[0])
stocks.head()
# Out:
#              Adj Close                                                      \
#            AXISBANK.NS BAJAJCON.NS BANKBARODA.NS BHARTIARTL.NS    CANBK.NS
# Date
# 2010-01-04  180.734619         NaN     83.074020    279.296417  301.685120
# 2010-01-05  184.505615         NaN     85.474243    283.719452  306.979828
# 2010-01-06  181.408661         NaN     85.997795    280.713501  308.492615
# 2010-01-07  182.692978         NaN     86.513275    282.903625  311.026550
# 2010-01-08  185.079468         NaN     86.859619    279.167603  306.752930
#
#                                                                          ...  \
#              COLPAL.NS   DABUR.NS HDFCBANK.NS HINDALCO.NS HINDUNILVR.NS  ...
# Date                                                                     ...
# 2010-01-04  261.899750  69.688766  153.989594  145.531647    206.463058  ...
# 2010-01-05  261.480164  71.372673  154.124985  155.945831    205.800079  ...
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',   'AXISBANK.NS'),
#             ('Adj Close',   'BAJAJCON.NS'),
#             ('Adj Close', 'BANKBARODA.NS'),
#             ('Adj Close', 'BHARTIARTL.NS'),
#             ('Adj Close',      'CANBK.NS'),
#             ('Adj Close',     'COLPAL.NS'),
#             ('Adj Close',      'DABUR.NS'),
#             ('Adj Close',   'HDFCBANK.NS'),
#             ('Adj Close',   'HINDALCO.NS'),
#             ('Adj Close', 'HINDUNILVR.NS'),
#             ...
#             (   'Volume',       'IDEA.NS'),
#             (   'Volume',       'INFY.NS'),
#             (   'Volume',        'ITC.NS'),
#             (   'Volume', 'JINDALSTEL.NS'),
#             (   'Volume',        'PNB.NS'),
#             (   'Volume',       'SBIN.NS'),
#             (   'Volume',   'TATACOMM.NS'),
#             (   'Volume',  'TATASTEEL.NS'),
#             (   'Volume',        'TCS.NS'),
#             (   'Volume',       'VEDL.NS')],
#            length=126)

# %% [markdown]
# ### Flat Index

# %%
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([  ('Adj Close', 'AXISBANK.NS'),   ('Adj Close', 'BAJAJCON.NS'),
#        ('Adj Close', 'BANKBARODA.NS'), ('Adj Close', 'BHARTIARTL.NS'),
#             ('Adj Close', 'CANBK.NS'),     ('Adj Close', 'COLPAL.NS'),
#             ('Adj Close', 'DABUR.NS'),   ('Adj Close', 'HDFCBANK.NS'),
#          ('Adj Close', 'HINDALCO.NS'), ('Adj Close', 'HINDUNILVR.NS'),
#        ...
#                 ('Volume', 'IDEA.NS'),          ('Volume', 'INFY.NS'),
#                  ('Volume', 'ITC.NS'),    ('Volume', 'JINDALSTEL.NS'),
#                  ('Volume', 'PNB.NS'),          ('Volume', 'SBIN.NS'),
#             ('Volume', 'TATACOMM.NS'),     ('Volume', 'TATASTEEL.NS'),
#                  ('Volume', 'TCS.NS'),          ('Volume', 'VEDL.NS')],
#       dtype='object', length=126)

# %%
stocks
# Out:
#             (Adj Close, AXISBANK.NS)  (Adj Close, BAJAJCON.NS)  \
# Date
# 2010-01-04                180.734619                       NaN
# 2010-01-05                184.505615                       NaN
# 2010-01-06                181.408661                       NaN
# 2010-01-07                182.692978                       NaN
# 2010-01-08                185.079468                       NaN
# ...                              ...                       ...
# 2023-09-15               1027.150024                233.199997
# 2023-09-18               1024.750000                231.699997
# 2023-09-20               1027.300049                229.899994
# 2023-09-21               1014.450012                227.600006
# 2023-09-22               1026.599976                231.550003
#
#             (Adj Close, BANKBARODA.NS)  (Adj Close, BHARTIARTL.NS)  \
# Date
# 2010-01-04                   83.074020                  279.296417
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks.columns
# Out:
# MultiIndex([('Adj Close',   'AXISBANK.NS'),
#             ('Adj Close',   'BAJAJCON.NS'),
#             ('Adj Close', 'BANKBARODA.NS'),
#             ('Adj Close', 'BHARTIARTL.NS'),
#             ('Adj Close',      'CANBK.NS'),
#             ('Adj Close',     'COLPAL.NS'),
#             ('Adj Close',      'DABUR.NS'),
#             ('Adj Close',   'HDFCBANK.NS'),
#             ('Adj Close',   'HINDALCO.NS'),
#             ('Adj Close', 'HINDUNILVR.NS'),
#             ...
#             (   'Volume',       'IDEA.NS'),
#             (   'Volume',       'INFY.NS'),
#             (   'Volume',        'ITC.NS'),
#             (   'Volume', 'JINDALSTEL.NS'),
#             (   'Volume',        'PNB.NS'),
#             (   'Volume',       'SBIN.NS'),
#             (   'Volume',   'TATACOMM.NS'),
#             (   'Volume',  'TATASTEEL.NS'),
#             (   'Volume',        'TCS.NS'),
#             (   'Volume',       'VEDL.NS')],
#            length=126)

# %%
stocks
# Out:
#               Adj Close                                                      \
#             AXISBANK.NS BAJAJCON.NS BANKBARODA.NS BHARTIARTL.NS    CANBK.NS
# Date
# 2010-01-04   180.734619         NaN     83.074020    279.296417  301.685120
# 2010-01-05   184.505615         NaN     85.474243    283.719452  306.979828
# 2010-01-06   181.408661         NaN     85.997795    280.713501  308.492615
# 2010-01-07   182.692978         NaN     86.513275    282.903625  311.026550
# 2010-01-08   185.079468         NaN     86.859619    279.167603  306.752930
# ...                 ...         ...           ...           ...         ...
# 2023-09-15  1027.150024  233.199997    210.800003    936.150024  364.850006
# 2023-09-18  1024.750000  231.699997    217.350006    920.200012  372.250000
# 2023-09-20  1027.300049  229.899994    213.449997    910.700012  371.000000
# 2023-09-21  1014.450012  227.600006    207.149994    917.950012  364.450012
# ...

# %%
stocks.loc[:, "Close"]
# Out:
#             AXISBANK.NS  BAJAJCON.NS  BANKBARODA.NS  BHARTIARTL.NS  \
# Date
# 2010-01-04   198.419998          NaN     103.139999     298.591614
# 2010-01-05   202.559998          NaN     106.120003     303.320221
# 2010-01-06   199.160004          NaN     106.769997     300.106598
# 2010-01-07   200.570007          NaN     107.410004     302.447968
# 2010-01-08   203.190002          NaN     107.839996     298.453888
# ...                 ...          ...            ...            ...
# 2023-09-15  1027.150024   233.199997     210.800003     936.150024
# 2023-09-18  1024.750000   231.699997     217.350006     920.200012
# 2023-09-20  1027.300049   229.899994     213.449997     910.700012
# 2023-09-21  1014.450012   227.600006     207.149994     917.950012
# 2023-09-22  1026.599976   231.550003     217.399994     913.200012
#
#               CANBK.NS    COLPAL.NS    DABUR.NS  HDFCBANK.NS  HINDALCO.NS  \
# Date
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# <ipython-input-54-4d420f08d23f>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close = stocks.loc[:, "Close"]

# %%
close.plot(figsize=(15,8), fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ### Normalise

# %% [markdown]
# ### try it for everyone

# %%
normclose = close.div(close.iloc[0]).mul(100)
normclose
# Out:
#             AXISBANK.NS  BAJAJCON.NS  BANKBARODA.NS  BHARTIARTL.NS  \
# Date
# 2010-01-04   100.000000          NaN     100.000000     100.000000
# 2010-01-05   102.086483          NaN     102.889280     101.583637
# 2010-01-06   100.372949          NaN     103.519485     100.507377
# 2010-01-07   101.083565          NaN     104.140008     101.291514
# 2010-01-08   102.403994          NaN     104.556910      99.953875
# ...                 ...          ...            ...            ...
# 2023-09-15   517.664567          NaN     204.382397     313.521874
# 2023-09-18   516.454999          NaN     210.732991     308.180126
# 2023-09-20   517.740177          NaN     206.951714     304.998523
# 2023-09-21   511.263996          NaN     200.843509     307.426589
# 2023-09-22   517.387353          NaN     210.781457     305.835787
#
#               CANBK.NS   COLPAL.NS    DABUR.NS  HDFCBANK.NS  HINDALCO.NS  \
# Date
# 2010-01-04  100.000000  100.000000  100.000000   100.000000   100.000000
# ...

# %% [markdown]
# ### Try to plot after normalisation

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
stocks = yf.download(ticker, start="2010-01-01", end="2024-01-01")
close = stocks.loc[:, "Close"].copy()
normclose = close.div(close.iloc[0]).mul(100)
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()
# Out:
# [*********************100%%**********************]  21 of 21 completed

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
#             AXISBANK.NS  BAJAJCON.NS  BANKBARODA.NS  BHARTIARTL.NS  CANBK.NS  \
# Date
# 2010-08-19     0.007611    -0.006128      -0.012353      -0.001586  0.018311
# 2010-08-20     0.002530    -0.036600      -0.001082      -0.013982 -0.015373
# 2010-08-23     0.010424    -0.000895       0.001324       0.022720  0.002649
# 2010-08-24    -0.006588    -0.013501      -0.021161       0.018434 -0.036240
# 2010-08-25    -0.007616     0.005586       0.003132      -0.019338  0.000294
#
#             COLPAL.NS  DABUR.NS  HDFCBANK.NS  HINDALCO.NS  HINDUNILVR.NS  ...  \
# Date                                                                      ...
# 2010-08-19  -0.018329  0.006341     0.017427     0.021011       0.017827  ...
# 2010-08-20  -0.005343  0.000242     0.000516    -0.006952      -0.018792  ...
# 2010-08-23  -0.012071  0.003877    -0.015551    -0.016802      -0.000186  ...
# 2010-08-24   0.019489  0.013034     0.005486    -0.040160       0.002976  ...
# ...

# %%
ret.describe()
# Out:
#        AXISBANK.NS  BAJAJCON.NS  BANKBARODA.NS  BHARTIARTL.NS     CANBK.NS  \
# count  3232.000000  3232.000000    3232.000000    3232.000000  3232.000000
# mean      0.000660     0.000345       0.000415       0.000548     0.000282
# std       0.022161     0.020873       0.026064       0.019654     0.027423
# min      -0.279108    -0.127667      -0.163771      -0.119529    -0.209351
# 25%      -0.010663    -0.010619      -0.013543      -0.010600    -0.014777
# 50%       0.000208    -0.000546       0.000000      -0.000265     0.000151
# 75%       0.011855     0.009537       0.013350       0.010827     0.014327
# max       0.194807     0.199853       0.314356       0.112908     0.387259
#
#          COLPAL.NS     DABUR.NS  HDFCBANK.NS  HINDALCO.NS  HINDUNILVR.NS  ...  \
# count  3232.000000  3232.000000  3232.000000  3232.000000    3232.000000  ...
# mean      0.000577     0.000640     0.000715     0.000636       0.000798  ...
# ...

# %%
summary = ret.describe().T.loc[:,('mean','std')]

# %%
summary['mean'] = summary['mean'] *252
summary['std'] = summary['std']*np.sqrt(252)

# %%
summary
# Out:
#                    mean       std
# AXISBANK.NS    0.166210  0.351799
# BAJAJCON.NS    0.086949  0.331352
# BANKBARODA.NS  0.104546  0.413746
# BHARTIARTL.NS  0.138022  0.312002
# CANBK.NS       0.071140  0.435330
# COLPAL.NS      0.145329  0.221547
# DABUR.NS       0.161284  0.240416
# HDFCBANK.NS    0.180257  0.235681
# HINDALCO.NS    0.160346  0.405864
# HINDUNILVR.NS  0.201215  0.237501
# ICICIBANK.NS   0.185947  0.328139
# IDEA.NS        0.074430  0.600109
# INFY.NS        0.152625  0.278109
# ITC.NS         0.142362  0.252943
# JINDALSTEL.NS  0.123024  0.493665
# PNB.NS        -0.003017  0.415631
# SBIN.NS        0.115987  0.339037
# TATACOMM.NS    0.204781  0.371701
# TATASTEEL.NS   0.142286  0.369749
# TCS.NS         0.196810  0.250959
# VEDL.NS        0.069587  0.439918

# %% [markdown]
# #### Plot the chart and better interpretation with chart analysis

# %%
summary.plot.scatter(x="std", y="mean", figsize=(12, 8), s=50, fontsize= 15)
for i in summary.index:
  plt.annotate(i, xy=(summary.loc[i, "std"]+ 0.002, summary.loc[i, "mean"]+ 0.002), size =15)

plt.xlabel("Annual Risk", fontsize=15)
plt.ylabel("Annual return", fontsize=15)
plt.title("Risk/Return", fontsize=22)
plt.show()

# %% [markdown]
# #### Correlation and Covariance

# %%
ret
# Out:
#             AXISBANK.NS  BAJAJCON.NS  BANKBARODA.NS  BHARTIARTL.NS  CANBK.NS  \
# Date
# 2010-08-19     0.007611    -0.006128      -0.012353      -0.001586  0.018311
# 2010-08-20     0.002530    -0.036600      -0.001082      -0.013982 -0.015373
# 2010-08-23     0.010424    -0.000895       0.001324       0.022720  0.002649
# 2010-08-24    -0.006588    -0.013501      -0.021161       0.018434 -0.036240
# 2010-08-25    -0.007616     0.005586       0.003132      -0.019338  0.000294
# ...                 ...          ...            ...            ...       ...
# 2023-09-15     0.006122    -0.019756      -0.005191       0.023171 -0.000411
# 2023-09-18    -0.002337    -0.006432       0.031072      -0.017038  0.020282
# 2023-09-20     0.002488    -0.007769      -0.017943      -0.010324 -0.003358
# 2023-09-21    -0.012509    -0.010004      -0.029515       0.007961 -0.017655
# 2023-09-22     0.011977     0.015817       0.049481      -0.005175  0.053368
#
# ...

# %%
ret.corr()
# Out:
#                AXISBANK.NS  BAJAJCON.NS  BANKBARODA.NS  BHARTIARTL.NS  \
# AXISBANK.NS       1.000000     0.227762       0.474505       0.269480
# BAJAJCON.NS       0.227762     1.000000       0.193396       0.104582
# BANKBARODA.NS     0.474505     0.193396       1.000000       0.239702
# BHARTIARTL.NS     0.269480     0.104582       0.239702       1.000000
# CANBK.NS          0.512947     0.218019       0.739645       0.269268
# COLPAL.NS         0.193565     0.153287       0.133128       0.154822
# DABUR.NS          0.217625     0.188216       0.156301       0.203073
# HDFCBANK.NS       0.520596     0.190295       0.332557       0.292031
# HINDALCO.NS       0.410097     0.183568       0.368767       0.289511
# HINDUNILVR.NS     0.212491     0.154722       0.103215       0.171078
# ICICIBANK.NS      0.690670     0.191350       0.523195       0.306140
# IDEA.NS           0.151465     0.088778       0.220778       0.379314
# ...

# %%
ret.cov()
# Out:
#                AXISBANK.NS  BAJAJCON.NS  BANKBARODA.NS  BHARTIARTL.NS  \
# AXISBANK.NS       0.000491     0.000105       0.000274       0.000117
# BAJAJCON.NS       0.000105     0.000436       0.000105       0.000043
# BANKBARODA.NS     0.000274     0.000105       0.000679       0.000123
# BHARTIARTL.NS     0.000117     0.000043       0.000123       0.000386
# CANBK.NS          0.000312     0.000125       0.000529       0.000145
# COLPAL.NS         0.000060     0.000045       0.000048       0.000042
# DABUR.NS          0.000073     0.000059       0.000062       0.000060
# HDFCBANK.NS       0.000171     0.000059       0.000129       0.000085
# HINDALCO.NS       0.000232     0.000098       0.000246       0.000145
# HINDUNILVR.NS     0.000070     0.000048       0.000040       0.000050
# ICICIBANK.NS      0.000316     0.000083       0.000282       0.000124
# IDEA.NS           0.000127     0.000070       0.000218       0.000282
# ...

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale = 1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True, annot_kws={"size":15}, vmax=0.6)
# Out:
# <Axes: >

# %% [markdown]
# ### You can easily select correlted values less than 0.4 for better selection
