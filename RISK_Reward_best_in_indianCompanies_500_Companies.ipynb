# %% [markdown]
# <a href="https://colab.research.google.com/github/tuxlimr/Celery_Preprocessing/blob/master/RISK_Reward_best_in_indianCompanies_500_Companies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nifty_500 = ['360ONE.NS',
'ABB.NS',
'ACC.NS',
'AIAENG.NS',
'APLAPOLLO.NS',
'AUBANK.NS',
'AARTIDRUGS.NS',
'AAVAS.NS',
'ABBOTINDIA.NS',
'ADANIENSOL.NS',
'ADANIENT.NS',
'ADANIGREEN.NS',
'ADANIPORTS.NS',
'ADANIPOWER.NS',
'ATGL.NS',
'AWL.NS',
'ABCAPITAL.NS',
'ABFRL.NS',
'AEGISCHEM.NS',
'AFFLE.NS',
'AJANTPHARM.NS',
'APLLTD.NS',
'ALKEM.NS',
'ALLCARGO.NS',
'AMARAJABAT.NS',
'AMBER.NS',
'AMBUJACEM.NS',
'ANGELONE.NS',
'APARINDS.NS',
'APOLLOHOSP.NS',
'APOLLOTYRE.NS',
'APTUS.NS',
'ASAHIINDIA.NS',
'ASHOKLEY.NS',
'ASIANPAINT.NS',
'ASTERDM.NS',
'ASTRAL.NS',
'AUROPHARMA.NS',
'AVANTIFEED.NS',
'DMART.NS',
'AXISBANK.NS',
'BEML.NS',
'BLS.NS',
'BSE.NS',
'BAJAJ-AUTO.NS',
'BAJFINANCE.NS',
'BAJAJFINSV.NS',
'BAJAJHLDNG.NS',
'BALKRISIND.NS',
'BALRAMCHIN.NS',
'BANDHANBNK.NS',
'BANKBARODA.NS',
'BANKINDIA.NS',
'MAHABANK.NS',
'BATAINDIA.NS',
'BERGEPAINT.NS',
'BDL.NS',
'BEL.NS',
'BHARATFORG.NS',
'BHEL.NS',
'BPCL.NS',
'BHARTIARTL.NS',
'BIKAJI.NS',
'BIOCON.NS',
'BIRLACORPN.NS',
'BSOFT.NS',
'BLUEDART.NS',
'BLUESTARCO.NS',
'BBTC.NS',
'BORORENEW.NS',
'BOSCHLTD.NS',
'BRIGADE.NS',
'BCG.NS',
'BRITANNIA.NS',
'MAPMYINDIA.NS',
'CCL.NS',
'CESC.NS',
'CGPOWER.NS',
'CIEINDIA.NS',
'CRISIL.NS',
'CSBBANK.NS',
'CAMPUS.NS',
'CANFINHOME.NS',
'CANBK.NS',
'CGCL.NS',
'CARBORUNIV.NS',
'CASTROLIND.NS',
'CEATLTD.NS',
'CENTRALBK.NS',
'CDSL.NS',
'CENTURYPLY.NS',
'CERA.NS',
'CHALET.NS',
'CHOLAHLDNG.NS',
'CHOLAFIN.NS',
'CIPLA.NS',
'CUB.NS',
'COALINDIA.NS',
'COCHINSHIP.NS',
'COFORGE.NS',
'COLPAL.NS',
'CAMS.NS',
'CONCOR.NS',
'CRAFTSMAN.NS',
'CREDITACC.NS',
'CROMPTON.NS',
'CUMMINSIND.NS',
'CYIENT.NS',
'DLF.NS',
'DABUR.NS',
'DALBHARAT.NS',
'DATAPATTNS.NS',
'DELHIVERY.NS',
'DELTACORP.NS',
'DEVYANI.NS',
'DIVISLAB.NS',
'DIXON.NS',
'LALPATHLAB.NS',
'DRREDDY.NS',
'EIHOTEL.NS',
'EPL.NS',
'EASEMYTRIP.NS',
'EICHERMOT.NS',
'ELGIEQUIP.NS',
'EMAMILTD.NS',
'ENDURANCE.NS',
'ENGINERSIN.NS',
'EQUITASBNK.NS',
'ERIS.NS',
'ESCORTS.NS',
'EXIDEIND.NS',
'FDC.NS',
'NYKAA.NS',
'FEDERALBNK.NS',
'FINCABLES.NS',
'FINPIPE.NS',
'FSL.NS',
'FIVESTAR.NS',
'FORTIS.NS',
'GRINFRA.NS',
'GAIL.NS',
'GMMPFAUDLR.NS',
'GMRINFRA.NS',
'GICRE.NS',
'GILLETTE.NS',
'GLAND.NS',
'GLAXO.NS',
'GLS.NS',
'GLENMARK.NS',
'MEDANTA.NS',
'GOCOLORS.NS',
'GPIL.NS',
'GODFRYPHLP.NS',
'GODREJCP.NS',
'GODREJPROP.NS',
'GRANULES.NS',
'GRAPHITE.NS',
'GRASIM.NS',
'GESHIP.NS',
'GRINDWELL.NS',
'GAEL.NS',
'GUJGASLTD.NS',
'GPPL.NS',
'GSPL.NS',
'HEG.NS',
'HCLTECH.NS',
'HDFCAMC.NS',
'HDFCBANK.NS',
'HDFCLIFE.NS',
'HFCL.NS',
'HLEGLAS.NS',
'HAPPSTMNDS.NS',
'HAVELLS.NS',
'HEROMOTOCO.NS',
'HINDALCO.NS',
'HAL.NS',
'HINDCOPPER.NS',
'HINDPETRO.NS',
'HINDUNILVR.NS',
'HINDZINC.NS',
'POWERINDIA.NS',
'HOMEFIRST.NS',
'HONAUT.NS',
'HUDCO.NS',
'ICICIBANK.NS',
'ICICIGI.NS',
'ICICIPRULI.NS',
'ISEC.NS',
'IDBI.NS',
'IDFCFIRSTB.NS',
'IDFC.NS',
'IIFL.NS',
'IRB.NS',
'IRCON.NS',
'ITC.NS',
'ITI.NS',
'INDIACEM.NS',
'IBULHSGFIN.NS',
'INDIAMART.NS',
'INDIANB.NS',
'IEX.NS',
'INDHOTEL.NS',
'IOC.NS',
'IOB.NS',
'IRCTC.NS',
'IRFC.NS',
'INDIGOPNTS.NS',
'IGL.NS',
'INDUSTOWER.NS',
'INDUSINDBK.NS',
'INFIBEAM.NS',
'NAUKRI.NS',
'INFY.NS',
'INGERRAND.NS',
'INTELLECT.NS',
'INDIGO.NS',
'IPCALAB.NS',
'JBCHEPHARM.NS',
'JKCEMENT.NS',
'JBMA.NS',
'JKLAKSHMI.NS',
'JMFINANCIL.NS',
'JSWENERGY.NS',
'JSWSTEEL.NS',
'JAMNAAUTO.NS',
'JINDALSAW.NS',
'JSL.NS',
'JINDALSTEL.NS',
'JUBLFOOD.NS',
'JUBLPHARMA.NS',
'JUSTDIAL.NS',
'JYOTHYLAB.NS',
'KEI.NS',
'KNRCON.NS',
'KPITTECH.NS',
'KRBL.NS',
'KSB.NS',
'KAJARIACER.NS',
'KPIL.NS',
'KALYANKJIL.NS',
'KANSAINER.NS',
'KARURVYSYA.NS',
'KAYNES.NS',
'KEC.NS',
'KFINTECH.NS',
'KIRLFER.NS',
'KOTAKBANK.NS',
'KIMS.NS',
'L&TFH.NS',
'LTTS.NS',
'LICHSGFIN.NS',
'LTIM.NS',
'LAXMIMACH.NS',
'LT.NS',
'LATENTVIEW.NS',
'LAURUSLABS.NS',
'LEMONTREE.NS',
'LICI.NS',
'LUPIN.NS',
'MMTC.NS',
'MRF.NS',
'MTARTECH.NS',
'LODHA.NS',
'MGL.NS',
'M&MFIN.NS',
'M&M.NS',
'MHRIL.NS',
'MAHLIFE.NS',
'MANAPPURAM.NS',
'MRPL.NS',
'MANKIND.NS',
'MARICO.NS',
'MARUTI.NS',
'MASTEK.NS',
'MFSL.NS',
'MAXHEALTH.NS',
'MAZDOCK.NS',
'MEDPLUS.NS',
'METROBRAND.NS',
'METROPOLIS.NS',
'MINDACORP.NS',
'MSUMI.NS',
'MOTILALOFS.NS',
'MPHASIS.NS',
'MCX.NS',
'MUTHOOTFIN.NS',
'NATCOPHARM.NS',
'NBCC.NS',
'NCC.NS',
'NHPC.NS',
'NLCINDIA.NS',
'NMDC.NS',
'NSLNISP.NS',
'NTPC.NS',
'NH.NS',
'NATIONALUM.NS',
'NAZARA.NS',
'NESTLEIND.NS',
'NETWORK18.NS',
'NAM-INDIA.NS',
'NUVOCO.NS',
'OBEROIRLTY.NS',
'ONGC.NS',
'OIL.NS',
'OLECTRA.NS',
'PAYTM.NS',
'OFSS.NS',
'ORIENTELEC.NS',
'POLICYBZR.NS',
'PNBHOUSING.NS',
'PNCINFRA.NS',
'PVRINOX.NS',
'PATANJALI.NS',
'PERSISTENT.NS',
'PETRONET.NS',
'PFIZER.NS',
'PHOENIXLTD.NS',
'PEL.NS',
'PPLPHARMA.NS',
'POLYMED.NS',
'POLYCAB.NS',
'POLYPLEX.NS',
'POONAWALLA.NS',
'PFC.NS',
'POWERGRID.NS',
'PRAJIND.NS',
'PRESTIGE.NS',
'PRINCEPIPE.NS',
'PRSMJOHNSN.NS',
'PGHL.NS',
'PGHH.NS',
'PNB.NS',
'QUESS.NS',
'RBLBANK.NS',
'RECLTD.NS',
'RHIM.NS',
'RITES.NS',
'RADICO.NS',
'RVNL.NS',
'RAINBOW.NS',
'RAJESHEXPO.NS',
'RATNAMANI.NS',
'RTNINDIA.NS',
'REDINGTON.NS',
'RELAXO.NS',
'RELIANCE.NS',
'RBA.NS',
'ROUTE.NS',
'SBICARD.NS',
'SBILIFE.NS',
'SJVN.NS',
'SKFINDIA.NS',
'SAFARI.NS',
'MOTHERSON.NS',
'SANOFI.NS',
'SAPPHIRE.NS',
'SAREGAMA.NS',
'SCHAEFFLER.NS',
'SFL.NS',
'SHOPERSTOP.NS',
'SHREECEM.NS',
'RENUKA.NS',
'SHRIRAMFIN.NS',
'SHYAMMETL.NS',
'SIEMENS.NS',
'SOBHA.NS',
'SONACOMS.NS',
'SONATSOFTW.NS',
'STARHEALTH.NS',
'SBIN.NS',
'SAIL.NS',
'SWSOLAR.NS',
'STLTECH.NS',
'SPARC.NS',
'SUNPHARMA.NS',
'SUNTV.NS',
'SUNDARMFIN.NS',
'SUNDRMFAST.NS',
'SUNTECK.NS',
'SUPRAJIT.NS',
'SUPREMEIND.NS',
'SUVENPHAR.NS',
'SUZLON.NS',
'SWANENERGY.NS',
'SYMPHONY.NS',
'SYNGENE.NS',
'SYRMA.NS',
'TTKPRESTIG.NS',
'TV18BRDCST.NS',
'TVSMOTOR.NS',
'TANLA.NS',
'TATACOMM.NS',
'TCS.NS',
'TATACONSUM.NS',
'TATAELXSI.NS',
'TATAINVEST.NS',
'TATAMTRDVR.NS',
'TATAMOTORS.NS',
'TATAPOWER.NS',
'TATASTEEL.NS',
'TTML.NS',
'TEAMLEASE.NS',
'TECHM.NS',
'TEJASNET.NS',
'NIACL.NS',
'RAMCOCEM.NS',
'THERMAX.NS',
'TIMKEN.NS',
'TITAN.NS',
'TORNTPHARM.NS',
'TORNTPOWER.NS',
'TRENT.NS',
'TRIVENI.NS',
'TRITURBINE.NS',
'TIINDIA.NS',
'UCOBANK.NS',
'UNOMINDA.NS',
'UTIAMC.NS',
'UJJIVANSFB.NS',
'ULTRACEMCO.NS',
'UNIONBANK.NS',
'UBL.NS',
'MCDOWELL-N.NS',
'USHAMART.NS',
'VGUARD.NS',
'VMART.NS',
'VIPIND.NS',
'VAIBHAVGBL.NS',
'VARROC.NS',
'VBL.NS',
'MANYAVAR.NS',
'VEDL.NS',
'VIJAYA.NS',
'IDEA.NS',
'VOLTAS.NS',
'WELCORP.NS',
'WESTLIFE.NS',
'WHIRLPOOL.NS',
'WIPRO.NS',
'YESBANK.NS',
'ZFCVINDIA.NS',
'ZEEL.NS',
'ZENSARTECH.NS',
'ZOMATO.NS',
'ZYDUSLIFE.NS',
'ZYDUSWELL.NS',
'ECLERX.NS',

]

# %%
summary_list = []

for i in nifty_500:
    stocks = yf.download(i, start="2013-01-01", end="2024-01-01")
    close = stocks['Close']
    normclose = close.div(close.iloc[0]).mul(100)
    ret = close.pct_change().dropna()
    summary = ret.describe().T[['mean', 'std']]
    summary['Stock'] = i
    summary['mean'] = summary['mean'] * 252
    summary['std'] = summary['std'] * np.sqrt(252)
    summary_list.append(summary)

# Concatenate the summaries for all stocks into a single DataFrame
summary_df = pd.concat(summary_list)
df = pd.DataFrame(summary_df).reset_index()
# Extract the values for 'Stock', 'Mean', and 'Std'
stock_values = df[df['index'] == 'Stock']['Close'].values
mean_values = df[df['index'] == 'mean']['Close'].values
std_values = df[df['index'] == 'std']['Close'].values

# Create a new DataFrame with the desired structure
df_pivot = pd.DataFrame({
    'Stock': stock_values,
    'Mean': mean_values,
    'Std': std_values
})

df_pivot
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
df_pivot
# Out:
#              Stock      Mean       Std
# 0        360ONE.NS  0.201624  0.399996
# 1           ABB.NS  0.221525  0.327682
# 2           ACC.NS  0.072446  0.278965
# 3        AIAENG.NS  0.270081  0.314351
# 4     APLAPOLLO.NS  0.517471  0.410091
# ..             ...       ...       ...
# 442  ZENSARTECH.NS  0.295972  0.403287
# 443      ZOMATO.NS  0.092744  0.565641
# 444   ZYDUSLIFE.NS  0.162504  0.312439
# 445   ZYDUSWELL.NS  0.147095  0.296688
# 446      ECLERX.NS  0.243682  0.374982
#
# [447 rows x 3 columns]
# No charts were generated by quickchart
