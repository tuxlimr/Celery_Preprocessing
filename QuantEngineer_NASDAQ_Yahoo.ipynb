# %% [markdown]
# <a href="https://colab.research.google.com/github/tuxlimr/Celery_Preprocessing/blob/master/QuantEngineer_NASDAQ_Yahoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ticker = ['AAPL','KO','SPY']

# %% [markdown]
# #### Pull Data

# %%
stocks = yf.download(ticker, start="2010-01-01", end="2021-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.645304   87.483192    7.643214  28.520000
# 2010-01-05    6.498750  18.419762   87.714760    7.656429  28.174999
# 2010-01-06    6.395380  18.413223   87.776535    7.534643  28.165001
# 2010-01-07    6.383557  18.367460   88.147064    7.520714  28.094999
# 2010-01-08    6.425997  18.027504   88.440399    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850555  49.167519  354.399078  131.970001  53.439999
# 2020-12-28  134.494766  49.829945  357.443695  136.690002  54.160000
# 2020-12-29  132.704010  49.802353  356.761780  134.869995  54.130001
# 2020-12-30  131.572479  50.087570  357.270752  133.720001  54.439999
# 2020-12-31  130.559006  50.455585  359.085999  132.690002  54.840000
#
# ...

# %%
stocks.to_csv("Stocks.csv")

# %%
stocks = pd.read_csv("Stocks.csv")

# %%
stocks.head()
# Out:
#    Unnamed: 0          Adj Close         Adj Close.1        Adj Close.2  \
# 0         NaN               AAPL                  KO                SPY
# 1        Date                NaN                 NaN                NaN
# 2  2010-01-04  6.487534046173096   18.64530372619629  87.48319244384766
# 3  2010-01-05  6.498749732971191  18.419761657714844  87.71475982666016
# 4  2010-01-06  6.395380020141602  18.413223266601562  87.77653503417969
#
#                Close             Close.1             Close.2  \
# 0               AAPL                  KO                 SPY
# 1                NaN                 NaN                 NaN
# 2  7.643214225769043  28.520000457763672  113.33000183105469
# 3  7.656428813934326  28.174999237060547  113.62999725341797
# 4  7.534643173217773  28.165000915527344  113.70999908447266
#
#                 High              High.1              High.2  \
# 0               AAPL                  KO                 SPY
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1])
stocks.head()
# Out:
#   Unnamed: 0_level_0 Adj Close                           Close             \
#   Unnamed: 0_level_1      AAPL         KO        SPY      AAPL         KO
# 0               Date       NaN        NaN        NaN       NaN        NaN
# 1         2010-01-04  6.487534  18.645304  87.483192  7.643214  28.520000
# 2         2010-01-05  6.498750  18.419762  87.714760  7.656429  28.174999
# 3         2010-01-06  6.395380  18.413223  87.776535  7.534643  28.165001
# 4         2010-01-07  6.383557  18.367460  88.147064  7.520714  28.094999
#
#                    High                              Low             \
#           SPY      AAPL         KO         SPY      AAPL         KO
# 0         NaN       NaN        NaN         NaN       NaN        NaN
# 1  113.330002  7.660714  28.610001  113.389999  7.585000  28.450001
# 2  113.629997  7.699643  28.495001  113.680000  7.616071  28.070000
# 3  113.709999  7.686786  28.219999  113.989998  7.526786  27.990000
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1], index_col=[0])
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.487534  18.645304  87.483192  7.643214  28.520000  113.330002
# 2010-01-05  6.498750  18.419762  87.714760  7.656429  28.174999  113.629997
# 2010-01-06  6.395380  18.413223  87.776535  7.534643  28.165001  113.709999
# 2010-01-07  6.383557  18.367460  88.147064  7.520714  28.094999  114.190002
# 2010-01-08  6.425997  18.027504  88.440399  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1], index_col=[0], parse_dates=[0])
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.487534  18.645304  87.483192  7.643214  28.520000  113.330002
# 2010-01-05  6.498750  18.419762  87.714760  7.656429  28.174999  113.629997
# 2010-01-06  6.395380  18.413223  87.776535  7.534643  28.165001  113.709999
# 2010-01-07  6.383557  18.367460  88.147064  7.520714  28.094999  114.190002
# 2010-01-08  6.425997  18.027504  88.440399  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %% [markdown]
# ### Flat Index

# %%
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.487534        18.645304         87.483192
# 2010-01-05           6.498750        18.419762         87.714760
# 2010-01-06           6.395380        18.413223         87.776535
# 2010-01-07           6.383557        18.367460         88.147064
# 2010-01-08           6.425997        18.027504         88.440399
# ...                       ...              ...               ...
# 2020-12-24         129.850555        49.167519        354.399078
# 2020-12-28         134.494766        49.829945        357.443695
# 2020-12-29         132.704010        49.802353        356.761780
# 2020-12-30         131.572479        50.087570        357.270752
# 2020-12-31         130.559006        50.455585        359.085999
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.645304   87.483192    7.643214  28.520000
# 2010-01-05    6.498750  18.419762   87.714760    7.656429  28.174999
# 2010-01-06    6.395380  18.413223   87.776535    7.534643  28.165001
# 2010-01-07    6.383557  18.367460   88.147064    7.520714  28.094999
# 2010-01-08    6.425997  18.027504   88.440399    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.850555  49.167519  354.399078  131.970001  53.439999
# 2020-12-28  134.494766  49.829945  357.443695  136.690002  54.160000
# 2020-12-29  132.704010  49.802353  356.761780  134.869995  54.130001
# 2020-12-30  131.572479  50.087570  357.270752  133.720001  54.439999
# 2020-12-31  130.559006  50.455585  359.085999  132.690002  54.840000
#
# ...

# %%
stocks.loc[:, "Close"]
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# <ipython-input-17-4d420f08d23f>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close = stocks.loc[:, "Close"]

# %%
close.plot(figsize=(15,8), fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ### Normalise

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %% [markdown]
# ### try it for everyone

# %%
normclose = close.div(close.iloc[0]).mul(100)
normclose
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %% [markdown]
# ### Try to plot after normalisation

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame()
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl["Diff"]= aapl.AAPL.sub(aapl.lag1)
aapl["% change"] = aapl.AAPL.div(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151
# 2010-01-08    7.570714    7.520714  0.050000  1.006648
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712
# 2020-12-28  136.690002  131.970001  4.720001  1.035766
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297
#
# [2769 rows x 4 columns]

# %% [markdown]
# ### You can use diff method instead of sub method used as earlier.

# %%
aapl["Diff2"]= aapl.AAPL.diff(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999
#
# [2769 rows x 5 columns]

# %%
del aapl['Diff2']

# %%
ret = aapl.pct_change()

# %%
ret
# Out:
#                 AAPL      lag1       Diff  % change
# Date
# 2010-01-04       NaN       NaN        NaN       NaN
# 2010-01-05  0.001729       NaN        NaN       NaN
# 2010-01-06 -0.015906  0.001729 -10.216000 -0.017605
# 2010-01-07 -0.001849 -0.015906  -0.885624  0.014285
# 2010-01-08  0.006648 -0.001849  -4.589552  0.008513
# ...              ...       ...        ...       ...
# 2020-12-24  0.007712 -0.006976  -2.097822  0.014791
# 2020-12-28  0.035766  0.007712   3.673294  0.027839
# 2020-12-29 -0.013315  0.035766  -1.385595 -0.047386
# 2020-12-30 -0.008527 -0.013315  -0.368138  0.004853
# 2020-12-31 -0.007703 -0.008527  -0.104344  0.000831
#
# [2769 rows x 4 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2767 entries, 2010-01-06 to 2020-12-31
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AAPL      2767 non-null   float64
#  1   lag1      2767 non-null   float64
#  2   Diff      2767 non-null   float64
#  3   % change  2767 non-null   float64
# dtypes: float64(4)
# memory usage: 108.1 KB

# %%
ret.AAPL.plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
daily_mean_return = ret.AAPL.mean()
daily_mean_return
# Out:
# 0.001190815280752763

# %%
var_return = ret.AAPL.var()
var_return
# Out:
# 0.0003184726015450653

# %% [markdown]
# #### Calculate standard deviation for daily

# %%
std_daily = np.sqrt(var_return)

# %%
std_daily
# Out:
# 0.017845800669767254

# %% [markdown]
# ### Calculate annual return

# %%
 annual_return = daily_mean_return * 252
 annual_return
# Out:
# 0.3000854507496963

# %%
annual_var_return = var_return * 252
annual_var_return
# Out:
# 0.08025509558935646

# %%
annual_std_return = np.sqrt(annual_var_return)
annual_std_return
# Out:
# 0.28329330311420436

# %% [markdown]
# ### Or Other way

# %%
ret.std()* np.sqrt(252)
# Out:
# AAPL        0.283293
# lag1        0.283281
# Diff             NaN
# % change    0.413234
# dtype: float64

# %%
ticker = ['AAPL','KO','SPY','MSFT',]
stocks = yf.download(ticker, start="2010-01-01", end="2021-01-01")
close = stocks.loc[:, "Close"].copy()
normclose = close.div(close.iloc[0]).mul(100)
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821  0.020308 -0.012720  0.001397

# %%
ret.describe()
# Out:
#               AAPL           KO         MSFT          SPY
# count  2768.000000  2768.000000  2768.000000  2768.000000
# mean      0.001191     0.000298     0.000841     0.000491
# std       0.017843     0.011088     0.016012     0.010909
# min      -0.128647    -0.096725    -0.147390    -0.109424
# 25%      -0.007123    -0.004698    -0.006939    -0.003532
# 50%       0.000903     0.000438     0.000654     0.000637
# 75%       0.010379     0.005706     0.008636     0.005421
# max       0.119808     0.064796     0.142169     0.090603

# %%
summary = ret.describe().T.loc[:,('mean','std')]

# %%
summary['mean'] = summary['mean'] *252
summary['std'] = summary['std']*np.sqrt(252)

# %%
summary
# Out:
#           mean       std
# AAPL  0.300134  0.283242
# KO    0.075091  0.176009
# MSFT  0.211915  0.254185
# SPY   0.123754  0.173170

# %% [markdown]
# #### Plot the chart and better interpretation with chart analysis

# %%
summary.plot.scatter(x="std", y="mean", figsize=(12, 8), s=50, fontsize= 15)
for i in summary.index:
  plt.annotate(i, xy=(summary.loc[i, "std"]+ 0.002, summary.loc[i, "mean"]+ 0.002), size =15)

plt.xlabel("Annual Risk", fontsize=15)
plt.ylabel("Annual return", fontsize=15)
plt.title("Risk/Return", fontsize=22)
plt.show()

# %% [markdown]
# #### Correlation and Covariance

# %%
ret
# Out:
#                 AAPL        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...
# 2020-12-24  0.007712  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.007348  0.003338  0.005081
#
# [2768 rows x 4 columns]

# %%
ret.corr()
# Out:
#           AAPL        KO      MSFT       SPY
# AAPL  1.000000  0.339213  0.554051  0.659557
# KO    0.339213  1.000000  0.429749  0.639324
# MSFT  0.554051  0.429749  1.000000  0.744601
# SPY   0.659557  0.639324  0.744601  1.000000

# %%
ret.cov()
# Out:
#           AAPL        KO      MSFT       SPY
# AAPL  0.000318  0.000067  0.000158  0.000128
# KO    0.000067  0.000123  0.000076  0.000077
# MSFT  0.000158  0.000076  0.000256  0.000130
# SPY   0.000128  0.000077  0.000130  0.000119

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale = 1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True, annot_kws={"size":15}, vmax=0.6)
# Out:
# <Axes: >

# %% [markdown]
# ### You can easily select correlted values less than 0.4 for better selection

# %% [markdown]
# #### Difference between Simple and Log return

# %%
df = pd.DataFrame(index= [2010,2011,2012], data = [100,50,400], columns=["price"])
df
# Out:
#       price
# 2010    100
# 2011     50
# 2012    400

# %%
simple_return = df.pct_change().dropna()
simple_return
# Out:
#       price
# 2011   -0.5
# 2012    7.0

# %%
simple_return.mean()
# Out:
# price    3.25
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %% [markdown]
# ### But we can do this well with log

# %%
log_returns= np.log(df/df.shift(1)).dropna()
log_returns
# Out:
#          price
# 2011 -0.693147
# 2012  2.079442

# %%
log_returns.mean()
# Out:
# price    0.693147
# dtype: float64

# %%
100*np.exp(log_returns.mean()*2)
# Out:
# price    400.0
# dtype: float64

# %% [markdown]
# #### Simple Moving Average

# %%
SPY = yf.download('SPY')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy = SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-09-25  432.230011
# 2023-09-26  425.880005
# 2023-09-27  426.049988
# 2023-09-28  428.519989
# 2023-09-29  427.480011
#
# [7723 rows x 1 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["SMA50"] = SPY.Close.rolling(window=50, min_periods=50).mean()
spy["SMA100"] = SPY.Close.rolling(window=100, min_periods=100).mean()

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %% [markdown]
# #### Check with Exponential Average

# %%
spy["EMA100"]= spy.Close.ewm(span=100, min_periods=100).mean()

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %% [markdown]
# ### Add Day in you current data set

# %%
spy["Day"] = spy.index.day_name()
spy
# Out:
#                  Close       SMA50      SMA100      EMA100        Day
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday
# ...                ...         ...         ...         ...        ...
# 2023-09-25  432.230011  446.415602  436.993001  435.978137     Monday
# 2023-09-26  425.880005  445.916403  437.171601  435.778174    Tuesday
# 2023-09-27  426.049988  445.353602  437.380801  435.585537  Wednesday
# 2023-09-28  428.519989  444.820002  437.539701  435.445625   Thursday
# 2023-09-29  427.480011  444.326002  437.687101  435.287890     Friday
#
# [7723 rows x 5 columns]

# %%
spy["quarter"] = spy.index.quarter
spy
# Out:
#                  Close       SMA50      SMA100      EMA100        Day  quarter
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2023-09-25  432.230011  446.415602  436.993001  435.978137     Monday        3
# 2023-09-26  425.880005  445.916403  437.171601  435.778174    Tuesday        3
# 2023-09-27  426.049988  445.353602  437.380801  435.585537  Wednesday        3
# 2023-09-28  428.519989  444.820002  437.539701  435.445625   Thursday        3
# 2023-09-29  427.480011  444.326002  437.687101  435.287890     Friday        3
#
# ...

# %% [markdown]
# ### Selection on the basis of selected Dates

# %%
selected_days = pd.date_range(start="2010-08-03", end="2011-08-03", freq='D')
selected_days
# Out:
# DatetimeIndex(['2010-08-03', '2010-08-04', '2010-08-05', '2010-08-06',
#                '2010-08-07', '2010-08-08', '2010-08-09', '2010-08-10',
#                '2010-08-11', '2010-08-12',
#                ...
#                '2011-07-25', '2011-07-26', '2011-07-27', '2011-07-28',
#                '2011-07-29', '2011-07-30', '2011-07-31', '2011-08-01',
#                '2011-08-02', '2011-08-03'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
spy.reindex(selected_days)
# Out:
#                  Close       SMA50      SMA100      EMA100        Day  quarter
# 2010-08-03  112.220001  108.558801  112.909200  110.704102    Tuesday      3.0
# 2010-08-04  112.970001  108.664001  112.884300  110.748972  Wednesday      3.0
# 2010-08-05  112.849998  108.764601  112.857900  110.790576   Thursday      3.0
# 2010-08-06  112.389999  108.869001  112.817700  110.822248     Friday      3.0
# 2010-08-07         NaN         NaN         NaN         NaN        NaN      NaN
# ...                ...         ...         ...         ...        ...      ...
# 2011-07-30         NaN         NaN         NaN         NaN        NaN      NaN
# 2011-07-31         NaN         NaN         NaN         NaN        NaN      NaN
# 2011-08-01  128.779999  130.977199  131.771399  130.888931     Monday      3.0
# 2011-08-02  125.489998  130.814799  131.726899  130.782021    Tuesday      3.0
# 2011-08-03  126.169998  130.696999  131.680199  130.690694  Wednesday      3.0
#
# [366 rows x 6 columns]

# %% [markdown]
# ### Fill Gaps for Non Working Days

# %%
spy.fillna(method='ffill')
# Out:
#                  Close       SMA50      SMA100      EMA100        Day  quarter
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2023-09-25  432.230011  446.415602  436.993001  435.978137     Monday        3
# 2023-09-26  425.880005  445.916403  437.171601  435.778174    Tuesday        3
# 2023-09-27  426.049988  445.353602  437.380801  435.585537  Wednesday        3
# 2023-09-28  428.519989  444.820002  437.539701  435.445625   Thursday        3
# 2023-09-29  427.480011  444.326002  437.687101  435.287890     Friday        3
#
# ...

# %%
spy[spy.fillna(method='ffill').Close.isnull()]
# Out:
# Empty DataFrame
# Columns: [Close, SMA50, SMA100, EMA100, Day, quarter]
# Index: []

# %%
spy.fillna(method='bfill')
# Out:
#                  Close       SMA50      SMA100      EMA100        Day  quarter
# Date
# 1993-01-29   43.937500   44.687500   44.685625   44.749197     Friday        1
# 1993-02-01   44.250000   44.687500   44.685625   44.749197     Monday        1
# 1993-02-02   44.343750   44.687500   44.685625   44.749197    Tuesday        1
# 1993-02-03   44.812500   44.687500   44.685625   44.749197  Wednesday        1
# 1993-02-04   45.000000   44.687500   44.685625   44.749197   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2023-09-25  432.230011  446.415602  436.993001  435.978137     Monday        3
# 2023-09-26  425.880005  445.916403  437.171601  435.778174    Tuesday        3
# 2023-09-27  426.049988  445.353602  437.380801  435.585537  Wednesday        3
# 2023-09-28  428.519989  444.820002  437.539701  435.445625   Thursday        3
# 2023-09-29  427.480011  444.326002  437.687101  435.287890     Friday        3
#
# ...

# %% [markdown]
# #### Download data on weekly basis

# %%
spy = yf.download("SPY", interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.941397
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.526791
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.313919
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.728529
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.207489
# ...                ...         ...         ...         ...         ...
# 2023-08-28  442.239990  453.670013  439.970001  451.190002  449.604095
# 2023-09-04  450.730011  451.059998  442.750000  445.519989  443.954010
# 2023-09-11  448.239990  451.079987  442.920013  443.369995  441.811584
# 2023-09-18  443.049988  444.970001  429.989990  430.420013  430.420013
# 2023-09-25  429.170013  432.269989  422.290009  427.480011  427.480011
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# ...

# %% [markdown]
# ### Cumulative Returns, drawdowns etc.

# %%
apple = yf.download('AAPL').Close.to_frame()
apple
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2023-09-25  176.080002
# 2023-09-26  171.960007
# 2023-09-27  170.429993
# 2023-09-28  170.690002
# 2023-09-29  171.210007
#
# [10790 rows x 1 columns]

# %%
apple['d_returns'] = np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2023-09-25  176.080002   0.007353
# 2023-09-26  171.960007  -0.023677
# 2023-09-27  170.429993  -0.008937
# 2023-09-28  170.690002   0.001524
# 2023-09-29  171.210007   0.003042
#
# [10790 rows x 2 columns]

# %%
apple.dropna(inplace=True)

apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2023-09-25  176.080002   0.007353
# 2023-09-26  171.960007  -0.023677
# 2023-09-27  170.429993  -0.008937
# 2023-09-28  170.690002   0.001524
# 2023-09-29  171.210007   0.003042
#
# [10789 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.195900921950713

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1333.95157064295

# %%
apple['cumm_returns'] = apple.d_returns.cumsum().apply(np.exp)
apple
# Out:
#                  Close  d_returns  cumm_returns
# Date
# 1980-12-15    0.121652  -0.053581      0.947829
# 1980-12-16    0.112723  -0.076231      0.878261
# 1980-12-17    0.115513   0.024450      0.899998
# 1980-12-18    0.118862   0.028580      0.926092
# 1980-12-19    0.126116   0.059239      0.982610
# ...                ...        ...           ...
# 2023-09-25  176.080002   0.007353   1371.895250
# 2023-09-26  171.960007  -0.023677   1339.795059
# 2023-09-27  170.429993  -0.008937   1327.874233
# 2023-09-28  170.690002   0.001524   1329.900052
# 2023-09-29  171.210007   0.003042   1333.951571
#
# [10789 rows x 3 columns]

# %%
apple.cumm_returns.plot(figsize=(12,8), title="Apple buy and Hold", fontsize=12)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.1680755428984688

# %% [markdown]
# ### So apple has given 17% average return on annual basis

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.45272956751829413

# %% [markdown]
# ### Calulate draw downs

# %%
apple['cummmax']= apple.cumm_returns.cummax()
apple
# Out:
#                  Close  d_returns  cumm_returns      cummmax
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829
# 1980-12-17    0.115513   0.024450      0.899998     0.947829
# 1980-12-18    0.118862   0.028580      0.926092     0.947829
# 1980-12-19    0.126116   0.059239      0.982610     0.982610
# ...                ...        ...           ...          ...
# 2023-09-25  176.080002   0.007353   1371.895250  1530.604356
# 2023-09-26  171.960007  -0.023677   1339.795059  1530.604356
# 2023-09-27  170.429993  -0.008937   1327.874233  1530.604356
# 2023-09-28  170.690002   0.001524   1329.900052  1530.604356
# 2023-09-29  171.210007   0.003042   1333.951571  1530.604356
#
# [10789 rows x 4 columns]

# %%
apple[['cumm_returns','cummmax']].plot(figsize=(12,8), title="Apple buy and Hold + cummmax", fontsize=12)
plt.show()

# %%
apple['drawdown'] =apple['cummmax']- apple['cumm_returns']

# %%
apple
# Out:
#                  Close  d_returns  cumm_returns      cummmax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2023-09-25  176.080002   0.007353   1371.895250  1530.604356  158.709105
# 2023-09-26  171.960007  -0.023677   1339.795059  1530.604356  190.809297
# 2023-09-27  170.429993  -0.008937   1327.874233  1530.604356  202.730122
# 2023-09-28  170.690002   0.001524   1329.900052  1530.604356  200.704303
# 2023-09-29  171.210007   0.003042   1333.951571  1530.604356  196.652785
#
# [10789 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %% [markdown]
# ### When did this drop down happened

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index=='2023-01-05')]
# Out:
#                  Close  d_returns  cumm_returns      cummmax    drawdown
# Date
# 2023-01-05  125.019997  -0.010661    974.070524  1418.097708  444.027184

# %% [markdown]
# ### Check what happend before initial drop down

# %%
apple.loc[(apple.index<='2023-01-05')]
# Out:
#                  Close  d_returns  cumm_returns      cummmax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2022-12-29  129.610001   0.027931   1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466   1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122    974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261    984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661    974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple['drawdown%'] =(apple['cummmax']- apple['cumm_returns'])/apple['cummmax']
apple
# Out:
#                  Close  d_returns  cumm_returns      cummmax    drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2023-09-25  176.080002   0.007353   1371.895250  1530.604356  158.709105
# 2023-09-26  171.960007  -0.023677   1339.795059  1530.604356  190.809297
# 2023-09-27  170.429993  -0.008937   1327.874233  1530.604356  202.730122
# 2023-09-28  170.690002   0.001524   1329.900052  1530.604356  200.704303
# 2023-09-29  171.210007   0.003042   1333.951571  1530.604356  196.652785
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# ...

# %%
apple['drawdown%'].max()
# Out:
# 0.82216567924191

# %%
apple['drawdown%'].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<='1997-12-23')]
# Out:
#                Close  d_returns  cumm_returns   cummmax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581      0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231      0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450      0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580      0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239      0.982610  0.982610  0.000000   0.000000
# ...              ...        ...           ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549      0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008      0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090      0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778      0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580      0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# #### SMA Strategy

# %%
data = apple.Close.loc[(apple.index>='1991-01-01')]
data = data.to_frame()
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-09-25  176.080002
# 2023-09-26  171.960007
# 2023-09-27  170.429993
# 2023-09-28  170.690002
# 2023-09-29  171.210007
#
# [8249 rows x 1 columns]

# %%
sma_s = 50
sma_l = 100

# %%
data['sma_s'] = data.Close.rolling(sma_s).mean()
data['sma_l'] = data.Close.rolling(sma_l).mean()
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-01-02    0.388393         NaN         NaN
# 1991-01-03    0.383929         NaN         NaN
# 1991-01-04    0.386161         NaN         NaN
# 1991-01-07    0.386161         NaN         NaN
# 1991-01-08    0.386161         NaN         NaN
# ...                ...         ...         ...
# 2023-09-25  176.080002  183.099001  181.984400
# 2023-09-26  171.960007  182.658401  182.029501
# 2023-09-27  170.429993  182.192401  182.075901
# 2023-09-28  170.690002  181.704200  182.047101
# 2023-09-29  171.210007  181.265800  182.024201
#
# [8249 rows x 3 columns]

# %%
data.plot(figsize=(12,8), title= f"Apple{sma_s}|{sma_l} ",fontsize=12)
# Out:
# <Axes: title={'center': 'Apple50|100 '}, xlabel='Date'>

# %%
data.loc['2016'].plot(figsize=(12,8), title= f"Apple{sma_s}|{sma_l} ",fontsize=12)
# Out:
# <Axes: title={'center': 'Apple50|100 '}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2023-09-25  176.080002  183.099001  181.984400
# 2023-09-26  171.960007  182.658401  182.029501
# 2023-09-27  170.429993  182.192401  182.075901
# 2023-09-28  170.690002  181.704200  182.047101
# 2023-09-29  171.210007  181.265800  182.024201
#
# [8150 rows x 3 columns]

# %%
data['position'] = np.where(data['sma_s']> data['sma_l'],1,-1)

data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2023-09-25  176.080002  183.099001  181.984400         1
# 2023-09-26  171.960007  182.658401  182.029501         1
# 2023-09-27  170.429993  182.192401  182.075901         1
# 2023-09-28  170.690002  181.704200  182.047101        -1
# 2023-09-29  171.210007  181.265800  182.024201        -1
#
# [8150 rows x 4 columns]

# %%
data.loc[:, ["sma_s", "sma_l","position"]].plot(figsize=(12,8), title= f"Apple{sma_s}|{sma_l} ",fontsize=12)
# Out:
# <Axes: title={'center': 'Apple50|100 '}, xlabel='Date'>

# %%
data.loc[:, ["sma_s", "sma_l","position"]].plot(figsize=(12,8), title= f"Apple{sma_s}|{sma_l} ",fontsize=12, secondary_y="position")
# Out:
# <Axes: title={'center': 'Apple50|100 '}, xlabel='Date'>

# %%
data.loc["2023", ["sma_s", "sma_l","position"]].plot(figsize=(12,8), title= f"Apple{sma_s}|{sma_l} ",fontsize=12, secondary_y="position")
# Out:
# <Axes: title={'center': 'Apple50|100 '}, xlabel='Date'>

# %%
data["return_b&h"]= np.log(data.Close.div(data.Close.shift(1)))
data
# Out:
#                  Close       sma_s       sma_l  position  return_b&h
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# ...                ...         ...         ...       ...         ...
# 2023-09-25  176.080002  183.099001  181.984400         1    0.007353
# 2023-09-26  171.960007  182.658401  182.029501         1   -0.023677
# 2023-09-27  170.429993  182.192401  182.075901         1   -0.008937
# 2023-09-28  170.690002  181.704200  182.047101        -1    0.001524
# 2023-09-29  171.210007  181.265800  182.024201        -1    0.003042
#
# [8150 rows x 5 columns]

# %%
data["Strategy"]= data["return_b&h"]*data.position.shift(1)
data
# Out:
#                  Close       sma_s       sma_l  position  return_b&h  Strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2023-09-25  176.080002  183.099001  181.984400         1    0.007353  0.007353
# 2023-09-26  171.960007  182.658401  182.029501         1   -0.023677 -0.023677
# 2023-09-27  170.429993  182.192401  182.075901         1   -0.008937 -0.008937
# 2023-09-28  170.690002  181.704200  182.047101        -1    0.001524  0.001524
# 2023-09-29  171.210007  181.265800  182.024201        -1    0.003042 -0.003042
#
# ...

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  return_b&h  Strategy
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209 -0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2023-09-25  176.080002  183.099001  181.984400         1    0.007353  0.007353
# 2023-09-26  171.960007  182.658401  182.029501         1   -0.023677 -0.023677
# 2023-09-27  170.429993  182.192401  182.075901         1   -0.008937 -0.008937
# 2023-09-28  170.690002  181.704200  182.047101        -1    0.001524  0.001524
# 2023-09-29  171.210007  181.265800  182.024201        -1    0.003042 -0.003042
#
# ...

# %%
data[['return_b&h','Strategy']].sum()
# Out:
# return_b&h    6.051953
# Strategy      2.084110
# dtype: float64

# %% [markdown]
# #### This means buy and Hold have better returns than immidiate buy and short

# %%
data[['return_b&h','Strategy']].sum().apply(np.exp)
# Out:
# return_b&h    424.942055
# Strategy        8.037432
# dtype: float64

# %%
data[['return_b&h','Strategy']].std()*np.sqrt(252) ## Annual return
# Out:
# return_b&h    0.436396
# Strategy      0.436536
# dtype: float64

# %% [markdown]
# ### Strategy adjusted with Long Bias

# %%
data['position2'] = np.where(data['sma_s']> data['sma_l'],1, 0 )

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  return_b&h  \
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# ...                ...         ...         ...       ...         ...
# 2023-09-25  176.080002  183.099001  181.984400         1    0.007353
# 2023-09-26  171.960007  182.658401  182.029501         1   -0.023677
# 2023-09-27  170.429993  182.192401  182.075901         1   -0.008937
# 2023-09-28  170.690002  181.704200  182.047101        -1    0.001524
# 2023-09-29  171.210007  181.265800  182.024201        -1    0.003042
#
#             Strategy  position2
# Date
# 1991-05-24  0.016483          1
# 1991-05-28  0.002721          1
# ...

# %%
data["Strategy2"]= data["return_b&h"]*data.position2.shift(1)
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  return_b&h  \
# Date
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# 1991-06-03    0.439732    0.513259    0.515223        -1    0.046761
# ...                ...         ...         ...       ...         ...
# 2023-09-25  176.080002  183.099001  181.984400         1    0.007353
# 2023-09-26  171.960007  182.658401  182.029501         1   -0.023677
# 2023-09-27  170.429993  182.192401  182.075901         1   -0.008937
# 2023-09-28  170.690002  181.704200  182.047101        -1    0.001524
# 2023-09-29  171.210007  181.265800  182.024201        -1    0.003042
#
#             Strategy  position2  Strategy2
# Date
# 1991-05-28  0.002721          1   0.002721
# ...

# %%
data[['return_b&h','Strategy2']].sum()
# Out:
# return_b&h    6.035470
# Strategy2     4.051548
# dtype: float64

# %%
data[['return_b&h','Strategy2']].sum().apply(np.exp)
# Out:
# return_b&h    417.995229
# Strategy2      57.486403
# dtype: float64

# %%
data[['return_b&h','Strategy2']].std()*np.sqrt(252) ## Annual return
# Out:
# return_b&h    0.436414
# Strategy2     0.337479
# dtype: float64

# %%
data[['Strategy','Strategy2']].std()*np.sqrt(252) ## Annual return
# Out:
# Strategy     0.436554
# Strategy2    0.337479
# dtype: float64

# %% [markdown]
# So buy and hold strategy (strategy2 )is better buy and short(strategy)

# %% [markdown]
# ### Create our test function

# %%
def test_strategy(stock,start,end,SMA):
  df = yf.download(stock,start=start, end=end)
  data = df.Close.to_frame()
  data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
  data["SMA_S"] = data.Close.rolling(int(SMA[0])).mean()
  data["SMA_L"] = data.Close.rolling(int(SMA[1])).mean()
  data.dropna(inplace=True)

  data['position'] = np.where(data['SMA_S']> data['SMA_L'],1,-1)
  data['strategy'] = data['returns']*data.position.shift(1)
  data.dropna(inplace=True)

  ret = np.exp(data['strategy'].sum())
  std = data['strategy'].std()*np.sqrt(252)
  return ret, std

# %%
test_strategy('MSFT', "2000-01-01","2020-01-01", (50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (0.39097954932295986, 0.2906766831415829)

# %%
test_strategy('AAPL', "2000-01-01","2020-01-01", (50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (16.540320732436786, 0.36699682903803943)

# %%
test_strategy('TSLA', "2000-01-01","2020-01-01", (50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (1.3908153866370587, 0.4956456904999671)

# %% [markdown]
# Create our First Back testing class

# %%
class SMABacktest():
  def __init__(self, symbol, SMA_S, SMA_L , start, end):
    self.symbol = symbol
    self.SMA_S = SMA_S
    self.SMA_L = SMA_L
    self.start = start
    self.end = end
    self.results = None
    self.get_data()

  def get_data(self):
      df = yf.download(self.symbol,start=self.start, end=self.end)
      data = df.Close.to_frame()
      data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
      data["SMA_S"] = data.Close.rolling(self.SMA_S).mean()
      data["SMA_L"] = data.Close.rolling(self.SMA_L).mean()
      data.dropna(inplace=True)
      self.data2 = data
      return data

  def test_results(self):
      data = self.data2.copy().dropna()
      data['position'] = np.where(data['SMA_S']> data['SMA_L'],1,-1)
      data['strategy'] = data['returns']*data.position.shift(1)
      data.dropna(inplace=True)
      data['returnbh'] = data['returns'].cumsum().apply(np.exp)
      data['strategy_results'] = data['strategy'].cumsum().apply(np.exp)
      perf = data['strategy_results'].iloc[-1]
      outperform = perf - data['returnbh'].iloc[-1]
      self.results =data

      ret = np.exp(data['strategy'].sum())
      std = data['strategy'].std()*np.sqrt(252)
      # return ret, std
      return round(perf, 6),  round(outperform, 6)

  def plot_results(self):
    if self.results is None:
        print("Run the test Please")
    else:
      title = (f"{self.symbol}| SMA_S={self.SMA_S} | SMA_L={self.SMA_L}")
      self.results[["returnbh","strategy_results"]].plot(title = title , figsize = (12,8))

# %%
tester = SMABacktest("SPY", 50,100, "2000-01-01", "2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.592726, 0.297824)

# %%
tester.plot_results()
