# %% [markdown]
# <a href="https://colab.research.google.com/github/tuxlimr/Celery_Preprocessing/blob/master/QuantEngineer_IndianBank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ticker = ['HDFCBANK.NS','PNB.NS','SBIN.NS', 'ICICIBANK.NS','AXISBANK.NS']

# %% [markdown]
# #### Pull Data

# %%
stocks = yf.download(ticker, start="2010-01-01", end="2024-01-01")
# Out:
# [*********************100%%**********************]  5 of 5 completed

# %%
stocks
# Out:
#              Adj Close                                                    \
#            AXISBANK.NS  HDFCBANK.NS ICICIBANK.NS      PNB.NS     SBIN.NS
# Date
# 2010-01-04  180.734589   153.989578   132.618225  153.879456  195.716766
# 2010-01-05  184.505600   154.124985   133.877060  156.257095  195.789398
# 2010-01-06  181.408630   154.228836   134.902161  155.517197  196.963898
# 2010-01-07  182.693024   154.630539   133.628311  153.380676  195.861969
# 2010-01-08  185.079468   154.833664   131.751419  153.605148  195.276855
# ...                ...          ...          ...         ...         ...
# 2023-09-04  982.250000  1584.550049   967.349976   67.400002  575.549988
# 2023-09-05  981.450012  1574.900024   968.400024   67.349998  573.000000
# 2023-09-06  965.049988  1595.500000   957.500000   65.699997  570.500000
# 2023-09-07  978.200012  1610.849976   965.650024   66.599998  579.049988
# 2023-09-08  980.299988  1623.400024   970.549988   66.849998  583.450012
#
# ...

# %%
stocks.to_csv("Stocks.csv")

# %%
stocks = pd.read_csv("Stocks.csv")

# %%
stocks.head()
# Out:
#    Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0         NaN         AXISBANK.NS         HDFCBANK.NS        ICICIBANK.NS
# 1        Date                 NaN                 NaN                 NaN
# 2  2010-01-04  180.73458862304688   153.9895782470703  132.61822509765625
# 3  2010-01-05  184.50559997558594  154.12498474121094  133.87705993652344
# 4  2010-01-06  181.40863037109375   154.2288360595703  134.90216064453125
#
#           Adj Close.3         Adj Close.4               Close  \
# 0              PNB.NS             SBIN.NS         AXISBANK.NS
# 1                 NaN                 NaN                 NaN
# 2  153.87945556640625  195.71676635742188   198.4199981689453
# 3  156.25709533691406  195.78939819335938  202.55999755859375
# 4  155.51719665527344  196.96389770507812  199.16000366210938
#
#               Close.1             Close.2             Close.3  ...  \
# 0         HDFCBANK.NS        ICICIBANK.NS              PNB.NS  ...
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1])
stocks.head()
# Out:
#   Unnamed: 0_level_0   Adj Close                                       \
#   Unnamed: 0_level_1 AXISBANK.NS HDFCBANK.NS ICICIBANK.NS      PNB.NS
# 0               Date         NaN         NaN          NaN         NaN
# 1         2010-01-04  180.734589  153.989578   132.618225  153.879456
# 2         2010-01-05  184.505600  154.124985   133.877060  156.257095
# 3         2010-01-06  181.408630  154.228836   134.902161  155.517197
# 4         2010-01-07  182.693024  154.630539   133.628311  153.380676
#
#                     Close                                       ...  \
#       SBIN.NS AXISBANK.NS HDFCBANK.NS ICICIBANK.NS      PNB.NS  ...
# 0         NaN         NaN         NaN          NaN         NaN  ...
# 1  195.716766  198.419998  170.570007   159.945450  185.100006  ...
# 2  195.789398  202.559998  170.720001   161.463638  187.960007  ...
# 3  196.963898  199.160004  170.835007   162.699997  187.070007  ...
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1], index_col=[0])
stocks.head()
# Out:
#              Adj Close                                                   \
#            AXISBANK.NS HDFCBANK.NS ICICIBANK.NS      PNB.NS     SBIN.NS
# Date
# 2010-01-04  180.734589  153.989578   132.618225  153.879456  195.716766
# 2010-01-05  184.505600  154.124985   133.877060  156.257095  195.789398
# 2010-01-06  181.408630  154.228836   134.902161  155.517197  196.963898
# 2010-01-07  182.693024  154.630539   133.628311  153.380676  195.861969
# 2010-01-08  185.079468  154.833664   131.751419  153.605148  195.276855
#
#                  Close                                                   ...  \
#            AXISBANK.NS HDFCBANK.NS ICICIBANK.NS      PNB.NS     SBIN.NS  ...
# Date                                                                     ...
# 2010-01-04  198.419998  170.570007   159.945450  185.100006  229.119995  ...
# 2010-01-05  202.559998  170.720001   161.463638  187.960007  229.205002  ...
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1], index_col=[0], parse_dates=[0])
stocks.head()
# Out:
#              Adj Close                                                   \
#            AXISBANK.NS HDFCBANK.NS ICICIBANK.NS      PNB.NS     SBIN.NS
# Date
# 2010-01-04  180.734589  153.989578   132.618225  153.879456  195.716766
# 2010-01-05  184.505600  154.124985   133.877060  156.257095  195.789398
# 2010-01-06  181.408630  154.228836   134.902161  155.517197  196.963898
# 2010-01-07  182.693024  154.630539   133.628311  153.380676  195.861969
# 2010-01-08  185.079468  154.833664   131.751419  153.605148  195.276855
#
#                  Close                                                   ...  \
#            AXISBANK.NS HDFCBANK.NS ICICIBANK.NS      PNB.NS     SBIN.NS  ...
# Date                                                                     ...
# 2010-01-04  198.419998  170.570007   159.945450  185.100006  229.119995  ...
# 2010-01-05  202.559998  170.720001   161.463638  187.960007  229.205002  ...
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',  'AXISBANK.NS'),
#             ('Adj Close',  'HDFCBANK.NS'),
#             ('Adj Close', 'ICICIBANK.NS'),
#             ('Adj Close',       'PNB.NS'),
#             ('Adj Close',      'SBIN.NS'),
#             (    'Close',  'AXISBANK.NS'),
#             (    'Close',  'HDFCBANK.NS'),
#             (    'Close', 'ICICIBANK.NS'),
#             (    'Close',       'PNB.NS'),
#             (    'Close',      'SBIN.NS'),
#             (     'High',  'AXISBANK.NS'),
#             (     'High',  'HDFCBANK.NS'),
#             (     'High', 'ICICIBANK.NS'),
#             (     'High',       'PNB.NS'),
#             (     'High',      'SBIN.NS'),
#             (      'Low',  'AXISBANK.NS'),
#             (      'Low',  'HDFCBANK.NS'),
#             (      'Low', 'ICICIBANK.NS'),
#             (      'Low',       'PNB.NS'),
#             (      'Low',      'SBIN.NS'),
#             (     'Open',  'AXISBANK.NS'),
#             (     'Open',  'HDFCBANK.NS'),
# ...

# %% [markdown]
# ### Flat Index

# %%
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([ ('Adj Close', 'AXISBANK.NS'),  ('Adj Close', 'HDFCBANK.NS'),
#        ('Adj Close', 'ICICIBANK.NS'),       ('Adj Close', 'PNB.NS'),
#             ('Adj Close', 'SBIN.NS'),      ('Close', 'AXISBANK.NS'),
#             ('Close', 'HDFCBANK.NS'),     ('Close', 'ICICIBANK.NS'),
#                  ('Close', 'PNB.NS'),          ('Close', 'SBIN.NS'),
#              ('High', 'AXISBANK.NS'),       ('High', 'HDFCBANK.NS'),
#             ('High', 'ICICIBANK.NS'),            ('High', 'PNB.NS'),
#                  ('High', 'SBIN.NS'),        ('Low', 'AXISBANK.NS'),
#               ('Low', 'HDFCBANK.NS'),       ('Low', 'ICICIBANK.NS'),
#                    ('Low', 'PNB.NS'),            ('Low', 'SBIN.NS'),
#              ('Open', 'AXISBANK.NS'),       ('Open', 'HDFCBANK.NS'),
#             ('Open', 'ICICIBANK.NS'),            ('Open', 'PNB.NS'),
#                  ('Open', 'SBIN.NS'),     ('Volume', 'AXISBANK.NS'),
#            ('Volume', 'HDFCBANK.NS'),    ('Volume', 'ICICIBANK.NS'),
# ...

# %%
stocks
# Out:
#             (Adj Close, AXISBANK.NS)  (Adj Close, HDFCBANK.NS)  \
# Date
# 2010-01-04                180.734589                153.989578
# 2010-01-05                184.505600                154.124985
# 2010-01-06                181.408630                154.228836
# 2010-01-07                182.693024                154.630539
# 2010-01-08                185.079468                154.833664
# ...                              ...                       ...
# 2023-09-04                982.250000               1584.550049
# 2023-09-05                981.450012               1574.900024
# 2023-09-06                965.049988               1595.500000
# 2023-09-07                978.200012               1610.849976
# 2023-09-08                980.299988               1623.400024
#
#             (Adj Close, ICICIBANK.NS)  (Adj Close, PNB.NS)  \
# Date
# 2010-01-04                 132.618225           153.879456
# 2010-01-05                 133.877060           156.257095
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks.columns
# Out:
# MultiIndex([('Adj Close',  'AXISBANK.NS'),
#             ('Adj Close',  'HDFCBANK.NS'),
#             ('Adj Close', 'ICICIBANK.NS'),
#             ('Adj Close',       'PNB.NS'),
#             ('Adj Close',      'SBIN.NS'),
#             (    'Close',  'AXISBANK.NS'),
#             (    'Close',  'HDFCBANK.NS'),
#             (    'Close', 'ICICIBANK.NS'),
#             (    'Close',       'PNB.NS'),
#             (    'Close',      'SBIN.NS'),
#             (     'High',  'AXISBANK.NS'),
#             (     'High',  'HDFCBANK.NS'),
#             (     'High', 'ICICIBANK.NS'),
#             (     'High',       'PNB.NS'),
#             (     'High',      'SBIN.NS'),
#             (      'Low',  'AXISBANK.NS'),
#             (      'Low',  'HDFCBANK.NS'),
#             (      'Low', 'ICICIBANK.NS'),
#             (      'Low',       'PNB.NS'),
#             (      'Low',      'SBIN.NS'),
#             (     'Open',  'AXISBANK.NS'),
#             (     'Open',  'HDFCBANK.NS'),
# ...

# %%
stocks
# Out:
#              Adj Close                                                    \
#            AXISBANK.NS  HDFCBANK.NS ICICIBANK.NS      PNB.NS     SBIN.NS
# Date
# 2010-01-04  180.734589   153.989578   132.618225  153.879456  195.716766
# 2010-01-05  184.505600   154.124985   133.877060  156.257095  195.789398
# 2010-01-06  181.408630   154.228836   134.902161  155.517197  196.963898
# 2010-01-07  182.693024   154.630539   133.628311  153.380676  195.861969
# 2010-01-08  185.079468   154.833664   131.751419  153.605148  195.276855
# ...                ...          ...          ...         ...         ...
# 2023-09-04  982.250000  1584.550049   967.349976   67.400002  575.549988
# 2023-09-05  981.450012  1574.900024   968.400024   67.349998  573.000000
# 2023-09-06  965.049988  1595.500000   957.500000   65.699997  570.500000
# 2023-09-07  978.200012  1610.849976   965.650024   66.599998  579.049988
# 2023-09-08  980.299988  1623.400024   970.549988   66.849998  583.450012
#
# ...

# %%
stocks.loc[:, "Close"]
# Out:
#             AXISBANK.NS  HDFCBANK.NS  ICICIBANK.NS      PNB.NS     SBIN.NS
# Date
# 2010-01-04   198.419998   170.570007    159.945450  185.100006  229.119995
# 2010-01-05   202.559998   170.720001    161.463638  187.960007  229.205002
# 2010-01-06   199.160004   170.835007    162.699997  187.070007  230.580002
# 2010-01-07   200.570007   171.279999    161.163635  184.500000  229.289993
# 2010-01-08   203.190002   171.505005    158.899994  184.770004  228.604996
# ...                 ...          ...           ...         ...         ...
# 2023-09-04   982.250000  1584.550049    967.349976   67.400002  575.549988
# 2023-09-05   981.450012  1574.900024    968.400024   67.349998  573.000000
# 2023-09-06   965.049988  1595.500000    957.500000   65.699997  570.500000
# 2023-09-07   978.200012  1610.849976    965.650024   66.599998  579.049988
# 2023-09-08   980.299988  1623.400024    970.549988   66.849998  583.450012
#
# [3380 rows x 5 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# <ipython-input-17-4d420f08d23f>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close = stocks.loc[:, "Close"]

# %%
close.plot(figsize=(15,8), fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
normclose = close.div(close.iloc[0]).mul(100)
normclose
# Out:
#             AXISBANK.NS  HDFCBANK.NS  ICICIBANK.NS      PNB.NS     SBIN.NS
# Date
# 2010-01-04   100.000000   100.000000    100.000000  100.000000  100.000000
# 2010-01-05   102.086483   100.087937    100.949191  101.545111  100.037101
# 2010-01-06   100.372949   100.155361    101.722179  101.064290  100.637224
# 2010-01-07   101.083565   100.416246    100.761626   99.675848  100.074196
# 2010-01-08   102.403994   100.548161     99.346367   99.821717   99.775227
# ...                 ...          ...           ...         ...         ...
# 2023-09-04   495.035787   928.973431    604.799934   36.412749  251.200244
# 2023-09-05   494.632608   923.315915    605.456439   36.385735  250.087296
# 2023-09-06   486.367300   935.393054    598.641600   35.494325  248.996165
# 2023-09-07   492.994668   944.392277    603.737103   35.980549  252.727828
# 2023-09-08   494.053017   951.749988    606.800624   36.115611  254.648230
#
# [3380 rows x 5 columns]

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()
