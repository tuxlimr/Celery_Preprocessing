# %% [markdown]
# <a href="https://colab.research.google.com/github/tuxlimr/Celery_Preprocessing/blob/master/QuantEngineer_IndianTelecom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ticker = ['BHARTIARTL.NS','TATACOMM.NS','IDEA.NS']

# %% [markdown]
# #### Pull Data

# %%
stocks = yf.download(ticker, start="2010-01-01", end="2024-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#                Adj Close                                 Close             \
#            BHARTIARTL.NS    IDEA.NS  TATACOMM.NS BHARTIARTL.NS    IDEA.NS
# Date
# 2010-01-04    279.296448  34.550125   294.374481    298.591614  35.092796
# 2010-01-05    283.719543  35.767101   312.520599    303.320221  36.328884
# 2010-01-06    280.713470  36.390427   309.308075    300.106598  36.962002
# 2010-01-07    282.903564  36.242012   306.833618    302.447968  36.811256
# 2010-01-08    279.167633  35.945190   314.647705    298.453888  36.509773
# ...                  ...        ...          ...           ...        ...
# 2023-09-04    865.299988  10.000000  1882.900024    865.299988  10.000000
# 2023-09-05    865.900024   9.900000  1866.000000    865.900024   9.900000
# 2023-09-06    880.299988  10.650000  1876.000000    880.299988  10.650000
# 2023-09-07    875.299988  10.500000  1889.800049    875.299988  10.500000
# 2023-09-08    885.849976  10.500000  1885.250000    885.849976  10.500000
#
# ...

# %%
stocks.to_csv("Stocks.csv")

# %%
stocks = pd.read_csv("Stocks.csv")

# %%
stocks.head()
# Out:
#    Unnamed: 0           Adj Close        Adj Close.1        Adj Close.2  \
# 0         NaN       BHARTIARTL.NS            IDEA.NS        TATACOMM.NS
# 1        Date                 NaN                NaN                NaN
# 2  2010-01-04  279.29644775390625  34.55012512207031  294.3744812011719
# 3  2010-01-05  283.71954345703125   35.7671012878418  312.5205993652344
# 4  2010-01-06   280.7134704589844  36.39042663574219  309.3080749511719
#
#                 Close             Close.1             Close.2  \
# 0       BHARTIARTL.NS             IDEA.NS         TATACOMM.NS
# 1                 NaN                 NaN                 NaN
# 2  298.59161376953125  35.092796325683594  339.04998779296875
# 3   303.3202209472656   36.32888412475586  359.95001220703125
# 4   300.1065979003906   36.96200180053711              356.25
#
#                  High             High.1             High.2  \
# 0       BHARTIARTL.NS            IDEA.NS        TATACOMM.NS
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1])
stocks.head()
# Out:
#   Unnamed: 0_level_0     Adj Close                                Close  \
#   Unnamed: 0_level_1 BHARTIARTL.NS    IDEA.NS TATACOMM.NS BHARTIARTL.NS
# 0               Date           NaN        NaN         NaN           NaN
# 1         2010-01-04    279.296448  34.550125  294.374481    298.591614
# 2         2010-01-05    283.719543  35.767101  312.520599    303.320221
# 3         2010-01-06    280.713470  36.390427  309.308075    300.106598
# 4         2010-01-07    282.903564  36.242012  306.833618    302.447968
#
#                                   High                                  Low  \
#      IDEA.NS TATACOMM.NS BHARTIARTL.NS    IDEA.NS TATACOMM.NS BHARTIARTL.NS
# 0        NaN         NaN           NaN        NaN         NaN           NaN
# 1  35.092796  339.049988    304.927032  35.514874  342.500000    297.352051
# 2  36.328884  359.950012    304.835205  36.600220  361.850006    298.867065
# 3  36.962002  356.250000    307.727478  37.112743  365.000000    299.417969
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1], index_col=[0])
stocks.head()
# Out:
#                Adj Close                                Close             \
#            BHARTIARTL.NS    IDEA.NS TATACOMM.NS BHARTIARTL.NS    IDEA.NS
# Date
# 2010-01-04    279.296448  34.550125  294.374481    298.591614  35.092796
# 2010-01-05    283.719543  35.767101  312.520599    303.320221  36.328884
# 2010-01-06    280.713470  36.390427  309.308075    300.106598  36.962002
# 2010-01-07    282.903564  36.242012  306.833618    302.447968  36.811256
# 2010-01-08    279.167633  35.945190  314.647705    298.453888  36.509773
#
#                                 High                                  Low  \
#            TATACOMM.NS BHARTIARTL.NS    IDEA.NS TATACOMM.NS BHARTIARTL.NS
# Date
# 2010-01-04  339.049988    304.927032  35.514874  342.500000    297.352051
# 2010-01-05  359.950012    304.835205  36.600220  361.850006    298.867065
# 2010-01-06  356.250000    307.727478  37.112743  365.000000    299.417969
# ...

# %%
stocks = pd.read_csv("Stocks.csv", header=[0,1], index_col=[0], parse_dates=[0])
stocks.head()
# Out:
#                Adj Close                                Close             \
#            BHARTIARTL.NS    IDEA.NS TATACOMM.NS BHARTIARTL.NS    IDEA.NS
# Date
# 2010-01-04    279.296448  34.550125  294.374481    298.591614  35.092796
# 2010-01-05    283.719543  35.767101  312.520599    303.320221  36.328884
# 2010-01-06    280.713470  36.390427  309.308075    300.106598  36.962002
# 2010-01-07    282.903564  36.242012  306.833618    302.447968  36.811256
# 2010-01-08    279.167633  35.945190  314.647705    298.453888  36.509773
#
#                                 High                                  Low  \
#            TATACOMM.NS BHARTIARTL.NS    IDEA.NS TATACOMM.NS BHARTIARTL.NS
# Date
# 2010-01-04  339.049988    304.927032  35.514874  342.500000    297.352051
# 2010-01-05  359.950012    304.835205  36.600220  361.850006    298.867065
# 2010-01-06  356.250000    307.727478  37.112743  365.000000    299.417969
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'BHARTIARTL.NS'),
#             ('Adj Close',       'IDEA.NS'),
#             ('Adj Close',   'TATACOMM.NS'),
#             (    'Close', 'BHARTIARTL.NS'),
#             (    'Close',       'IDEA.NS'),
#             (    'Close',   'TATACOMM.NS'),
#             (     'High', 'BHARTIARTL.NS'),
#             (     'High',       'IDEA.NS'),
#             (     'High',   'TATACOMM.NS'),
#             (      'Low', 'BHARTIARTL.NS'),
#             (      'Low',       'IDEA.NS'),
#             (      'Low',   'TATACOMM.NS'),
#             (     'Open', 'BHARTIARTL.NS'),
#             (     'Open',       'IDEA.NS'),
#             (     'Open',   'TATACOMM.NS'),
#             (   'Volume', 'BHARTIARTL.NS'),
#             (   'Volume',       'IDEA.NS'),
#             (   'Volume',   'TATACOMM.NS')],
#            )

# %% [markdown]
# ### Flat Index

# %%
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([('Adj Close', 'BHARTIARTL.NS'),       ('Adj Close', 'IDEA.NS'),
#          ('Adj Close', 'TATACOMM.NS'),     ('Close', 'BHARTIARTL.NS'),
#                  ('Close', 'IDEA.NS'),       ('Close', 'TATACOMM.NS'),
#             ('High', 'BHARTIARTL.NS'),            ('High', 'IDEA.NS'),
#               ('High', 'TATACOMM.NS'),       ('Low', 'BHARTIARTL.NS'),
#                    ('Low', 'IDEA.NS'),         ('Low', 'TATACOMM.NS'),
#             ('Open', 'BHARTIARTL.NS'),            ('Open', 'IDEA.NS'),
#               ('Open', 'TATACOMM.NS'),    ('Volume', 'BHARTIARTL.NS'),
#                 ('Volume', 'IDEA.NS'),      ('Volume', 'TATACOMM.NS')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, BHARTIARTL.NS)  (Adj Close, IDEA.NS)  \
# Date
# 2010-01-04                  279.296448             34.550125
# 2010-01-05                  283.719543             35.767101
# 2010-01-06                  280.713470             36.390427
# 2010-01-07                  282.903564             36.242012
# 2010-01-08                  279.167633             35.945190
# ...                                ...                   ...
# 2023-09-04                  865.299988             10.000000
# 2023-09-05                  865.900024              9.900000
# 2023-09-06                  880.299988             10.650000
# 2023-09-07                  875.299988             10.500000
# 2023-09-08                  885.849976             10.500000
#
#             (Adj Close, TATACOMM.NS)  (Close, BHARTIARTL.NS)  \
# Date
# 2010-01-04                294.374481              298.591614
# 2010-01-05                312.520599              303.320221
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'BHARTIARTL.NS'),
#             ('Adj Close',       'IDEA.NS'),
#             ('Adj Close',   'TATACOMM.NS'),
#             (    'Close', 'BHARTIARTL.NS'),
#             (    'Close',       'IDEA.NS'),
#             (    'Close',   'TATACOMM.NS'),
#             (     'High', 'BHARTIARTL.NS'),
#             (     'High',       'IDEA.NS'),
#             (     'High',   'TATACOMM.NS'),
#             (      'Low', 'BHARTIARTL.NS'),
#             (      'Low',       'IDEA.NS'),
#             (      'Low',   'TATACOMM.NS'),
#             (     'Open', 'BHARTIARTL.NS'),
#             (     'Open',       'IDEA.NS'),
#             (     'Open',   'TATACOMM.NS'),
#             (   'Volume', 'BHARTIARTL.NS'),
#             (   'Volume',       'IDEA.NS'),
#             (   'Volume',   'TATACOMM.NS')],
#            )

# %%
stocks
# Out:
#                Adj Close                                 Close             \
#            BHARTIARTL.NS    IDEA.NS  TATACOMM.NS BHARTIARTL.NS    IDEA.NS
# Date
# 2010-01-04    279.296448  34.550125   294.374481    298.591614  35.092796
# 2010-01-05    283.719543  35.767101   312.520599    303.320221  36.328884
# 2010-01-06    280.713470  36.390427   309.308075    300.106598  36.962002
# 2010-01-07    282.903564  36.242012   306.833618    302.447968  36.811256
# 2010-01-08    279.167633  35.945190   314.647705    298.453888  36.509773
# ...                  ...        ...          ...           ...        ...
# 2023-09-04    865.299988  10.000000  1882.900024    865.299988  10.000000
# 2023-09-05    865.900024   9.900000  1866.000000    865.900024   9.900000
# 2023-09-06    880.299988  10.650000  1876.000000    880.299988  10.650000
# 2023-09-07    875.299988  10.500000  1889.800049    875.299988  10.500000
# 2023-09-08    885.849976  10.500000  1885.250000    885.849976  10.500000
#
# ...

# %%
stocks.loc[:, "Close"]
# Out:
#             BHARTIARTL.NS    IDEA.NS  TATACOMM.NS
# Date
# 2010-01-04     298.591614  35.092796   339.049988
# 2010-01-05     303.320221  36.328884   359.950012
# 2010-01-06     300.106598  36.962002   356.250000
# 2010-01-07     302.447968  36.811256   353.399994
# 2010-01-08     298.453888  36.509773   362.399994
# ...                   ...        ...          ...
# 2023-09-04     865.299988  10.000000  1882.900024
# 2023-09-05     865.900024   9.900000  1866.000000
# 2023-09-06     880.299988  10.650000  1876.000000
# 2023-09-07     875.299988  10.500000  1889.800049
# 2023-09-08     885.849976  10.500000  1885.250000
#
# [3380 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# <ipython-input-135-4d420f08d23f>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close = stocks.loc[:, "Close"]

# %%
close.plot(figsize=(15,8), fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
normclose = close.div(close.iloc[0]).mul(100)
normclose
# Out:
#             BHARTIARTL.NS     IDEA.NS  TATACOMM.NS
# Date
# 2010-01-04     100.000000  100.000000   100.000000
# 2010-01-05     101.583637  103.522341   106.164290
# 2010-01-06     100.507377  105.326465   105.073002
# 2010-01-07     101.291514  104.896903   104.232416
# 2010-01-08      99.953875  104.037800   106.886892
# ...                   ...         ...          ...
# 2023-09-04     289.793801   28.495877   555.345846
# 2023-09-05     289.994757   28.210917   550.361323
# 2023-09-06     294.817385   30.348108   553.310741
# 2023-09-07     293.142857   29.920671   557.380952
# 2023-09-08     296.676107   29.920671   556.038952
#
# [3380 rows x 3 columns]

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()
