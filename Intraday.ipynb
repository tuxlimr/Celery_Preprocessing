# %% [markdown]
# <a href="https://colab.research.google.com/github/tuxlimr/Celery_Preprocessing/blob/master/Intraday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance --quiet

# %%
import yfinance as yf
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

# %%
NiftyIT = ['INFY.NS', 'TCS.NS']
NiftyMetal = ['HINDALCO.NS','TATASTEEL.NS','JINDALSTEL.NS', 'VEDL.NS','ICICIBANK.NS']
NiftyTelecom = ['BHARTIARTL.NS','TATACOMM.NS','IDEA.NS']
NityBank = ['HDFCBANK.NS','PNB.NS','SBIN.NS', 'ICICIBANK.NS','AXISBANK.NS']

NSE = NiftyIT + NiftyMetal + NiftyTelecom + NityBank

# %%
NSE
# Out:
# ['INFY.NS',
#  'TCS.NS',
#  'HINDALCO.NS',
#  'TATASTEEL.NS',
#  'JINDALSTEL.NS',
#  'VEDL.NS',
#  'ICICIBANK.NS',
#  'BHARTIARTL.NS',
#  'TATACOMM.NS',
#  'IDEA.NS',
#  'HDFCBANK.NS',
#  'PNB.NS',
#  'SBIN.NS',
#  'ICICIBANK.NS',
#  'AXISBANK.NS']

# %%
stocks = yf.download(NSE, start="2010-01-01", end="2024-01-01")
# Out:
# [*********************100%%**********************]  14 of 14 completed

# %%
stocks
# Out:
#               Adj Close                                                      \
#             AXISBANK.NS BHARTIARTL.NS  HDFCBANK.NS HINDALCO.NS ICICIBANK.NS
# Date
# 2010-01-04   180.734634    279.296448   153.989563  145.531662   132.618256
# 2010-01-05   184.505600    283.719513   154.124969  155.945831   133.877045
# 2010-01-06   181.408630    280.713562   154.228775  152.251923   134.902176
# 2010-01-07   182.692978    282.903564   154.630569  155.901321   133.628296
# 2010-01-08   185.079453    279.167572   154.833679  154.254623   131.751419
# ...                 ...           ...          ...         ...          ...
# 2023-09-12  1000.900024    890.400024  1636.900024  477.750000   990.500000
# 2023-09-13  1014.450012    915.150024  1643.900024  483.200012   989.799988
# 2023-09-14  1020.900024    914.950012  1642.900024  497.350006   987.700012
# 2023-09-15  1027.150024    936.150024  1661.750000  496.549988   992.450012
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks.columns
# Out:
# MultiIndex([('Adj Close',   'AXISBANK.NS'),
#             ('Adj Close', 'BHARTIARTL.NS'),
#             ('Adj Close',   'HDFCBANK.NS'),
#             ('Adj Close',   'HINDALCO.NS'),
#             ('Adj Close',  'ICICIBANK.NS'),
#             ('Adj Close',       'IDEA.NS'),
#             ('Adj Close',       'INFY.NS'),
#             ('Adj Close', 'JINDALSTEL.NS'),
#             ('Adj Close',        'PNB.NS'),
#             ('Adj Close',       'SBIN.NS'),
#             ('Adj Close',   'TATACOMM.NS'),
#             ('Adj Close',  'TATASTEEL.NS'),
#             ('Adj Close',        'TCS.NS'),
#             ('Adj Close',       'VEDL.NS'),
#             (    'Close',   'AXISBANK.NS'),
#             (    'Close', 'BHARTIARTL.NS'),
#             (    'Close',   'HDFCBANK.NS'),
#             (    'Close',   'HINDALCO.NS'),
#             (    'Close',  'ICICIBANK.NS'),
#             (    'Close',       'IDEA.NS'),
#             (    'Close',       'INFY.NS'),
# ...

# %%
stocks.loc[:, "Close"].tail()
# Out:
#             AXISBANK.NS  BHARTIARTL.NS  HDFCBANK.NS  HINDALCO.NS  \
# Date
# 2023-09-12  1000.900024     890.400024  1636.900024   477.750000
# 2023-09-13  1014.450012     915.150024  1643.900024   483.200012
# 2023-09-14  1020.900024     914.950012  1642.900024   497.350006
# 2023-09-15  1027.150024     936.150024  1661.750000   496.549988
# 2023-09-18  1026.699951     931.000000  1638.900024   489.000000
#
#             ICICIBANK.NS  IDEA.NS      INFY.NS  JINDALSTEL.NS     PNB.NS  \
# Date
# 2023-09-12    990.500000     10.5  1501.099976     685.849976  66.849998
# 2023-09-13    989.799988     11.0  1498.349976     691.799988  72.550003
# 2023-09-14    987.700012     10.9  1506.949951     711.049988  73.699997
# 2023-09-15    992.450012     11.7  1511.599976     711.450012  74.150002
# 2023-09-18    991.099976     11.2  1494.650024     701.000000  78.750000
#
#                SBIN.NS  TATACOMM.NS  TATASTEEL.NS       TCS.NS     VEDL.NS
# Date
# ...

# %%
# @title
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the stock symbol (TCS)
stock_symbol = "TCS"

# Fetch historical data for TCS stock
tcs_data = yf.download(stock_symbol, period="5y")  # You can adjust the period as needed

# Calculate the 200-day moving average
tcs_data['200_MA'] = tcs_data['Adj Close'].rolling(window=200).mean()

# Plot the stock's adjusted close price and the 200-day moving average
plt.figure(figsize=(12, 6))
plt.plot(tcs_data.index, tcs_data['Adj Close'], label='TCS Adj Close', color='blue')
plt.plot(tcs_data.index, tcs_data['200_MA'], label='200-day MA', color='red')
plt.title(f'{stock_symbol} Stock Price with 200-day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the stock symbol (TCS)
stock_symbol = "TCS"

# Fetch historical data for TCS stock
tcs_data = yf.download(stock_symbol, period="5y")  # You can adjust the period as needed

# Calculate the 200-day moving average
tcs_data['200_MA'] = tcs_data['Adj Close'].rolling(window=200).mean()

# Create a new column for buy and sell signals
tcs_data['Signal'] = 0  # Initialize the signal column with zeros

# Generate buy signals (1) when the closing price crosses above the 200-day MA
tcs_data.loc[tcs_data['Adj Close'] > tcs_data['200_MA'], 'Signal'] = 1

# Generate sell signals (-1) when the closing price crosses below the 200-day MA
tcs_data.loc[tcs_data['Adj Close'] < tcs_data['200_MA'], 'Signal'] = -1

# Plot the stock's adjusted close price, the 200-day moving average, and buy/sell signals
plt.figure(figsize=(12, 6))
plt.plot(tcs_data.index, tcs_data['Adj Close'], label='TCS Adj Close', color='blue')
plt.plot(tcs_data.index, tcs_data['200_MA'], label='200-day MA', color='red')

# Filter buy and sell signals
buy_signals = tcs_data[tcs_data['Signal'] == 1]
sell_signals = tcs_data[tcs_data['Signal'] == -1]

# Plot buy signals as green triangles (^)
plt.scatter(buy_signals.index, buy_signals['Adj Close'], marker='^', color='green', label='Buy Signal', alpha=1)

# Plot sell signals as red inverted triangles (v)
plt.scatter(sell_signals.index, sell_signals['Adj Close'], marker='v', color='red', label='Sell Signal', alpha=1)

plt.title(f'{stock_symbol} Stock Price with 200-day MA and Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# Print the buy and sell signals
print("Buy Signals:")
print(buy_signals[['Adj Close', '200_MA']])
print("\nSell Signals:")
print(sell_signals[['Adj Close', '200_MA']])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Buy Signals:
#             Adj Close     200_MA
# Date
# 2019-07-05   7.225870   6.906595
# 2019-07-08   7.029565   6.891638
# 2019-07-09   7.160435   6.876495
# 2019-07-10   6.954783   6.859949
# 2020-06-05   3.640000   3.473572
# ...               ...        ...
# 2021-11-10  13.330000  13.081200
# 2021-11-11  13.180000  13.080750
# 2021-11-12  13.460000  13.079900
# 2021-11-16  13.140000  13.059300
# 2021-11-18  13.090000  13.033850
#
# [264 rows x 2 columns]
#
# Sell Signals:
#             Adj Close    200_MA
# Date
# 2019-07-03   6.749130  6.920523
# 2019-07-11   6.552826  6.840412
# 2019-07-12   6.515435  6.820268
# 2019-07-15   6.403261  6.801385
# 2019-07-16   6.580870  6.783718
# ...               ...       ...
# 2023-09-11   2.120000  3.596550
# 2023-09-12   2.140000  3.583350
# 2023-09-13   2.210000  3.570200
# 2023-09-14   2.320000  3.558250
# 2023-09-15   2.330000  3.546800
#
# [795 rows x 2 columns]

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the stock symbol (TCS)
stock_symbol = "TCS"

# Fetch historical data for TCS stock
tcs_data = yf.download(stock_symbol, period="5y")  # You can adjust the period as needed

# Calculate the 90-day and 200-day moving averages
tcs_data['90_DMA'] = tcs_data['Adj Close'].rolling(window=90).mean()
tcs_data['200_MA'] = tcs_data['Adj Close'].rolling(window=200).mean()

# Create columns for buy and sell signals based on both moving averages
tcs_data['Signal_90_DMA'] = 0  # Initialize the 90 DMA signal column with zeros
tcs_data['Signal_200_MA'] = 0  # Initialize the 200 MA signal column with zeros

# Generate buy signals (1) when the 90 DMA crosses above the 200 MA
tcs_data.loc[tcs_data['90_DMA'] > tcs_data['200_MA'], 'Signal_90_DMA'] = 1

# Generate sell signals (-1) when the 90 DMA crosses below the 200 MA
tcs_data.loc[tcs_data['90_DMA'] < tcs_data['200_MA'], 'Signal_90_DMA'] = -1

# Plot the stock's adjusted close price, the 90 DMA, the 200 MA, and buy/sell signals for both
plt.figure(figsize=(12, 6))
plt.plot(tcs_data.index, tcs_data['Adj Close'], label='TCS Adj Close', color='blue')
plt.plot(tcs_data.index, tcs_data['90_DMA'], label='90-day DMA', color='orange')
plt.plot(tcs_data.index, tcs_data['200_MA'], label='200-day MA', color='red')

# Filter buy and sell signals for both 90 DMA and 200 MA
buy_signals_90_DMA = tcs_data[tcs_data['Signal_90_DMA'] == 1]
sell_signals_90_DMA = tcs_data[tcs_data['Signal_90_DMA'] == -1]

# Plot buy signals for 90 DMA as green triangles (^)
plt.scatter(buy_signals_90_DMA.index, buy_signals_90_DMA['Adj Close'], marker='^', color='green', label='Buy Signal (90 DMA)', alpha=1)

# Plot sell signals for 90 DMA as red inverted triangles (v)
plt.scatter(sell_signals_90_DMA.index, sell_signals_90_DMA['Adj Close'], marker='v', color='red', label='Sell Signal (90 DMA)', alpha=1)

plt.title(f'{stock_symbol} Stock Price with 90-day DMA and 200-day MA Crossovers')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# Print the buy and sell signals for both 90 DMA and 200 MA
print("Buy Signals (90 DMA):")
print(buy_signals_90_DMA[['Adj Close', '90_DMA', '200_MA']])
print("\nSell Signals (90 DMA):")
print(sell_signals_90_DMA[['Adj Close', '90_DMA', '200_MA']])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Buy Signals (90 DMA):
#             Adj Close     90_DMA     200_MA
# Date
# 2019-07-03   6.749130   7.259522   6.920523
# 2019-07-05   7.225870   7.270116   6.906595
# 2019-07-08   7.029565   7.279360   6.891638
# 2019-07-09   7.160435   7.287981   6.876495
# 2019-07-10   6.954783   7.294628   6.859949
# ...               ...        ...        ...
# 2021-08-06  11.210000  13.116889  12.862250
# 2021-08-09  11.490000  13.059667  12.874950
# 2021-08-10  12.230000  13.013111  12.888550
# 2021-08-11  12.300000  12.968889  12.900850
# 2021-08-12  12.190000  12.923111  12.916200
#
# [282 rows x 3 columns]
#
# Sell Signals (90 DMA):
#             Adj Close    90_DMA    200_MA
# Date
# 2019-09-10   4.720653  6.155232  6.171669
# 2019-09-11   4.786087  6.115867  6.168724
# 2019-09-12   4.617826  6.073698  6.165406
# 2019-09-13   4.571087  6.032464  6.161526
# 2019-09-16   4.468261  5.989048  6.157647
# ...

# %% [markdown]
# ### Create main function

# %%
# @title
def main_function(stock="TCS"):
  # Fetch historical data for stock
  data = yf.download(stock, period="5y")  # You can adjust the period as needed

  # Calculate the 90-day and 200-day moving averages
  data['90_DMA'] = data['Close'].rolling(window=90).mean()
  data['200_MA'] = data['Close'].rolling(window=200).mean()

  # Create columns for buy and sell signals based on both moving averages
  data['Signal_90_DMA'] = 0  # Initialize the 90 DMA signal column with zeros
  data['Signal_200_MA'] = 0  # Initialize the 200 MA signal column with zeros

  # Generate buy signals (1) when the 90 DMA crosses above the 200 MA
  data.loc[data['90_DMA'] > data['200_MA'], 'Signal_90_DMA'] = 1

  # Generate sell signals (-1) when the 90 DMA crosses below the 200 MA
  data.loc[data['90_DMA'] < data['200_MA'], 'Signal_90_DMA'] = -1

  # Plot the stock's adjusted close price, the 90 DMA, the 200 MA, and buy/sell signals for both
  plt.figure(figsize=(12, 6))
  plt.plot(data.index, data['Adj Close'], label='TCS Adj Close', color='blue')
  plt.plot(data.index, data['90_DMA'], label='90-day DMA', color='orange')
  plt.plot(data.index, data['200_MA'], label='200-day MA', color='red')

  # Filter buy and sell signals for both 90 DMA and 200 MA
  buy_signals_90_DMA = data[data['Signal_90_DMA'] == 1]
  sell_signals_90_DMA = data[data['Signal_90_DMA'] == -1]

  # Plot buy signals for 90 DMA as green triangles (^)
  plt.scatter(buy_signals_90_DMA.index, buy_signals_90_DMA['Adj Close'], marker='^', color='green', label='Buy Signal (90 DMA)', alpha=1)

  # Plot sell signals for 90 DMA as red inverted triangles (v)
  plt.scatter(sell_signals_90_DMA.index, sell_signals_90_DMA['Adj Close'], marker='v', color='red', label='Sell Signal (90 DMA)', alpha=1)

  plt.title(f'{stock} Stock Price with 90-day DMA and 200-day MA Crossovers')
  plt.xlabel('Date')
  plt.ylabel('Price')
  plt.legend()
  plt.grid(True)

  # Show the plot
  plt.show()

  # Print the buy and sell signals for both 90 DMA and 200 MA
  print("Buy Signals (90 DMA):")
  print(buy_signals_90_DMA[['Adj Close', '90_DMA', '200_MA']])
  print("\nSell Signals (90 DMA):")
  print(sell_signals_90_DMA[['Adj Close', '90_DMA', '200_MA']])

# %% [markdown]
# #### Run for Multiple Stocks

# %%
# @title
for i in NSE:
  main_function(i)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Buy Signals (90 DMA):
#               Adj Close       90_DMA       200_MA
# Date
# 2019-07-15   694.780945   732.409997   711.831998
# 2019-07-16   699.684204   732.971663   712.160748
# 2019-07-17   707.975098   733.552219   712.532748
# 2019-07-18   706.682373   734.221108   712.969749
# 2019-07-19   700.174561   734.808886   713.305499
# ...                 ...          ...          ...
# 2023-04-06  1384.416992  1517.803341  1506.876754
# 2023-04-10  1389.966675  1515.627785  1507.078253
# 2023-04-11  1369.082153  1513.151118  1507.038253
# 2023-04-12  1390.648315  1510.855008  1506.930253
# 2023-04-13  1352.578979  1507.878341  1506.690003
#
# [613 rows x 3 columns]
#
# Sell Signals (90 DMA):
#               Adj Close       90_DMA       200_MA
# Date
# 2020-01-06   673.988892   744.698885   744.851997
# 2020-01-07   664.000183   743.873330   744.935247
# 2020-01-08   655.151733   742.936108   744.991497
# ...
